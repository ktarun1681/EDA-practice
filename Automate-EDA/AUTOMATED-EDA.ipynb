# %% [markdown]
# ## Automated EDA Techniques

# %%
# !pip install pandas_profiling
# Out:
# Requirement already satisfied: pandas_profiling in /Users/tarunsingh/opt/anaconda3/lib/python3.9/site-packages (3.1.0)
# Requirement already satisfied: missingno>=0.4.2 in /Users/tarunsingh/opt/anaconda3/lib/python3.9/site-packages (from pandas_profiling) (0.5.0)
# Requirement already satisfied: scipy>=1.4.1 in /Users/tarunsingh/opt/anaconda3/lib/python3.9/site-packages (from pandas_profiling) (1.7.1)
# Requirement already satisfied: markupsafe~=2.0.1 in /Users/tarunsingh/opt/anaconda3/lib/python3.9/site-packages (from pandas_profiling) (2.0.1)
# Requirement already satisfied: htmlmin>=0.1.12 in /Users/tarunsingh/opt/anaconda3/lib/python3.9/site-packages (from pandas_profiling) (0.1.12)
# Requirement already satisfied: requests>=2.24.0 in /Users/tarunsingh/opt/anaconda3/lib/python3.9/site-packages (from pandas_profiling) (2.26.0)
# Requirement already satisfied: phik>=0.11.1 in /Users/tarunsingh/opt/anaconda3/lib/python3.9/site-packages (from pandas_profiling) (0.12.0)
# Requirement already satisfied: tqdm>=4.48.2 in /Users/tarunsingh/opt/anaconda3/lib/python3.9/site-packages (from pandas_profiling) (4.62.3)
# Requirement already satisfied: tangled-up-in-unicode==0.1.0 in /Users/tarunsingh/opt/anaconda3/lib/python3.9/site-packages (from pandas_profiling) (0.1.0)
# Requirement already satisfied: numpy>=1.16.0 in /Users/tarunsingh/opt/anaconda3/lib/python3.9/site-packages (from pandas_profiling) (1.20.3)
# Requirement already satisfied: PyYAML>=5.0.0 in /Users/tarunsingh/opt/anaconda3/lib/python3.9/site-packages (from pandas_profiling) (6.0)
# Requirement already satisfied: pydantic>=1.8.1 in /Users/tarunsingh/opt/anaconda3/lib/python3.9/site-packages (from pandas_profiling) (1.9.0)
# Requirement already satisfied: pandas!=1.0.0,!=1.0.1,!=1.0.2,!=1.1.0,>=0.25.3 in /Users/tarunsingh/opt/anaconda3/lib/python3.9/site-packages (from pandas_profiling) (1.3.4)
# Requirement already satisfied: seaborn>=0.10.1 in /Users/tarunsingh/opt/anaconda3/lib/python3.9/site-packages (from pandas_profiling) (0.11.2)
# Requirement already satisfied: matplotlib>=3.2.0 in /Users/tarunsingh/opt/anaconda3/lib/python3.9/site-packages (from pandas_profiling) (3.4.3)
# Requirement already satisfied: jinja2>=2.11.1 in /Users/tarunsingh/opt/anaconda3/lib/python3.9/site-packages (from pandas_profiling) (2.11.3)
# Requirement already satisfied: multimethod>=1.4 in /Users/tarunsingh/opt/anaconda3/lib/python3.9/site-packages (from pandas_profiling) (1.7)
# Requirement already satisfied: joblib~=1.0.1 in /Users/tarunsingh/opt/anaconda3/lib/python3.9/site-packages (from pandas_profiling) (1.0.1)
# Requirement already satisfied: visions[type_image_path]==0.7.4 in /Users/tarunsingh/opt/anaconda3/lib/python3.9/site-packages (from pandas_profiling) (0.7.4)
# Requirement already satisfied: attrs>=19.3.0 in /Users/tarunsingh/opt/anaconda3/lib/python3.9/site-packages (from visions[type_image_path]==0.7.4->pandas_profiling) (21.2.0)
# Requirement already satisfied: networkx>=2.4 in /Users/tarunsingh/opt/anaconda3/lib/python3.9/site-packages (from visions[type_image_path]==0.7.4->pandas_profiling) (2.6.3)
# Requirement already satisfied: Pillow in /Users/tarunsingh/opt/anaconda3/lib/python3.9/site-packages (from visions[type_image_path]==0.7.4->pandas_profiling) (8.4.0)
# Requirement already satisfied: imagehash in /Users/tarunsingh/opt/anaconda3/lib/python3.9/site-packages (from visions[type_image_path]==0.7.4->pandas_profiling) (4.2.1)
# Requirement already satisfied: pyparsing>=2.2.1 in /Users/tarunsingh/opt/anaconda3/lib/python3.9/site-packages (from matplotlib>=3.2.0->pandas_profiling) (3.0.4)
# Requirement already satisfied: cycler>=0.10 in /Users/tarunsingh/opt/anaconda3/lib/python3.9/site-packages (from matplotlib>=3.2.0->pandas_profiling) (0.10.0)
# Requirement already satisfied: python-dateutil>=2.7 in /Users/tarunsingh/opt/anaconda3/lib/python3.9/site-packages (from matplotlib>=3.2.0->pandas_profiling) (2.8.2)
# Requirement already satisfied: kiwisolver>=1.0.1 in /Users/tarunsingh/opt/anaconda3/lib/python3.9/site-packages (from matplotlib>=3.2.0->pandas_profiling) (1.3.1)
# Requirement already satisfied: six in /Users/tarunsingh/opt/anaconda3/lib/python3.9/site-packages (from cycler>=0.10->matplotlib>=3.2.0->pandas_profiling) (1.16.0)
# Requirement already satisfied: pytz>=2017.3 in /Users/tarunsingh/opt/anaconda3/lib/python3.9/site-packages (from pandas!=1.0.0,!=1.0.1,!=1.0.2,!=1.1.0,>=0.25.3->pandas_profiling) (2021.3)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /Users/tarunsingh/opt/anaconda3/lib/python3.9/site-packages (from pydantic>=1.8.1->pandas_profiling) (3.10.0.2)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /Users/tarunsingh/opt/anaconda3/lib/python3.9/site-packages (from requests>=2.24.0->pandas_profiling) (1.26.7)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/tarunsingh/opt/anaconda3/lib/python3.9/site-packages (from requests>=2.24.0->pandas_profiling) (2021.10.8)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /Users/tarunsingh/opt/anaconda3/lib/python3.9/site-packages (from requests>=2.24.0->pandas_profiling) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in /Users/tarunsingh/opt/anaconda3/lib/python3.9/site-packages (from requests>=2.24.0->pandas_profiling) (3.2)
# Requirement already satisfied: PyWavelets in /Users/tarunsingh/opt/anaconda3/lib/python3.9/site-packages (from imagehash->visions[type_image_path]==0.7.4->pandas_profiling) (1.1.1)

# %%
import pandas_profiling

# %%
import seaborn as sns

df = sns.load_dataset('tips')
df.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
# from pandas_profiling import ProfileReport
# profile = ProfileReport(df, explorative=True, dark_mode=True)
# profile.to_file('output.html')

# %%
# from pandas_profiling import ProfileReport
# import seaborn as sns
# df2 = sns.load_dataset('titanic')
# profile = ProfileReport(df2, explorative=True, dark_mode=True)
# profile.to_file('titanic.html')
# Out:
# Summarize dataset:   0%|          | 0/5 [00:00<?, ?it/s]

# %%
# !pip install dtale
# Out:
# Collecting dtale
#   Using cached dtale-2.0.0-py2.py3-none-any.whl (11.4 MB)
# Requirement already satisfied: numpy in /Users/tarunsingh/opt/anaconda3/lib/python3.9/site-packages (from dtale) (1.20.3)
# Requirement already satisfied: itsdangerous in /Users/tarunsingh/opt/anaconda3/lib/python3.9/site-packages (from dtale) (2.0.1)
# Requirement already satisfied: networkx in /Users/tarunsingh/opt/anaconda3/lib/python3.9/site-packages (from dtale) (2.6.3)
# Requirement already satisfied: openpyxl in /Users/tarunsingh/opt/anaconda3/lib/python3.9/site-packages (from dtale) (3.0.9)
# Collecting dash-colorscales
#   Downloading dash_colorscales-0.0.4.tar.gz (62 kB)
#      |████████████████████████████████| 62 kB 345 kB/s eta 0:00:01
# Requirement already satisfied: pandas in /Users/tarunsingh/opt/anaconda3/lib/python3.9/site-packages (from dtale) (1.3.4)
# Collecting dash>=2.0.0
#   Downloading dash-2.2.0-py3-none-any.whl (8.5 MB)
#      |████████████████████████████████| 8.5 MB 136 kB/s eta 0:00:01
# Collecting strsimpy
#   Using cached strsimpy-0.2.1-py3-none-any.whl (45 kB)
# Collecting dash-daq
#   Using cached dash_daq-0.5.0.tar.gz (642 kB)
# Requirement already satisfied: cycler in /Users/tarunsingh/opt/anaconda3/lib/python3.9/site-packages (from dtale) (0.10.0)
# Requirement already satisfied: xlrd in /Users/tarunsingh/opt/anaconda3/lib/python3.9/site-packages (from dtale) (2.0.1)
# Collecting ppscore
#   Downloading ppscore-1.2.0.tar.gz (47 kB)
#      |████████████████████████████████| 47 kB 707 kB/s eta 0:00:01
# Requirement already satisfied: matplotlib in /Users/tarunsingh/opt/anaconda3/lib/python3.9/site-packages (from dtale) (3.4.3)
# Collecting xarray
#   Downloading xarray-0.21.1-py3-none-any.whl (865 kB)
#      |████████████████████████████████| 865 kB 1.0 MB/s eta 0:00:01
# Requirement already satisfied: scipy in /Users/tarunsingh/opt/anaconda3/lib/python3.9/site-packages (from dtale) (1.7.1)
# Collecting flask-ngrok
#   Using cached flask_ngrok-0.0.25-py3-none-any.whl (3.1 kB)
# Collecting dash-bootstrap-components
#   Using cached dash_bootstrap_components-1.0.3-py3-none-any.whl (209 kB)
# Requirement already satisfied: requests in /Users/tarunsingh/opt/anaconda3/lib/python3.9/site-packages (from dtale) (2.26.0)
# Requirement already satisfied: Flask in /Users/tarunsingh/opt/anaconda3/lib/python3.9/site-packages (from dtale) (1.1.2)
# Collecting lz4
#   Downloading lz4-4.0.0-cp39-cp39-macosx_10_9_x86_64.whl (90 kB)
#      |████████████████████████████████| 90 kB 915 kB/s eta 0:00:01
# Collecting kaleido
#   Downloading kaleido-0.2.1-py2.py3-none-macosx_10_11_x86_64.whl (85.2 MB)
#      |████████████████████████████████| 85.2 MB 175 kB/s  eta 0:00:01    |██████████████████████▌         | 60.0 MB 3.7 MB/s eta 0:00:07
# Requirement already satisfied: statsmodels in /Users/tarunsingh/opt/anaconda3/lib/python3.9/site-packages (from dtale) (0.12.2)
# Requirement already satisfied: et-xmlfile in /Users/tarunsingh/opt/anaconda3/lib/python3.9/site-packages (from dtale) (1.1.0)
# Collecting missingno<=0.4.2
#   Downloading missingno-0.4.2-py3-none-any.whl (9.7 kB)
# Collecting Flask-Compress
#   Downloading Flask_Compress-1.10.1-py3-none-any.whl (7.9 kB)
# Collecting squarify
#   Downloading squarify-0.4.3-py3-none-any.whl (4.3 kB)
# Requirement already satisfied: six in /Users/tarunsingh/opt/anaconda3/lib/python3.9/site-packages (from dtale) (1.16.0)
# Collecting plotly>=5.0.0
#   Downloading plotly-5.6.0-py2.py3-none-any.whl (27.7 MB)
#      |████████████████████████████████| 27.7 MB 38 kB/s  eta 0:00:01     |███████████▉                    | 10.2 MB 1.2 MB/s eta 0:00:16     |██████████████████████████▋     | 23.0 MB 2.0 MB/s eta 0:00:03
# Requirement already satisfied: scikit-learn==0.24.2 in /Users/tarunsingh/opt/anaconda3/lib/python3.9/site-packages (from dtale) (0.24.2)
# Requirement already satisfied: seaborn in /Users/tarunsingh/opt/anaconda3/lib/python3.9/site-packages (from dtale) (0.11.2)
# Requirement already satisfied: future>=0.14.0 in /Users/tarunsingh/opt/anaconda3/lib/python3.9/site-packages (from dtale) (0.18.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /Users/tarunsingh/opt/anaconda3/lib/python3.9/site-packages (from scikit-learn==0.24.2->dtale) (2.2.0)
# Requirement already satisfied: joblib>=0.11 in /Users/tarunsingh/opt/anaconda3/lib/python3.9/site-packages (from scikit-learn==0.24.2->dtale) (1.0.1)
# Collecting dash-html-components==2.0.0
#   Downloading dash_html_components-2.0.0.tar.gz (3.8 kB)
# Collecting dash-table==5.0.0
#   Downloading dash_table-5.0.0.tar.gz (3.4 kB)
# Collecting dash-core-components==2.0.0
#   Downloading dash_core_components-2.0.0.tar.gz (3.4 kB)
# Requirement already satisfied: Jinja2>=2.10.1 in /Users/tarunsingh/opt/anaconda3/lib/python3.9/site-packages (from Flask->dtale) (2.11.3)
# Requirement already satisfied: Werkzeug>=0.15 in /Users/tarunsingh/opt/anaconda3/lib/python3.9/site-packages (from Flask->dtale) (2.0.2)
# Requirement already satisfied: click>=5.1 in /Users/tarunsingh/opt/anaconda3/lib/python3.9/site-packages (from Flask->dtale) (8.0.3)
# Requirement already satisfied: MarkupSafe>=0.23 in /Users/tarunsingh/opt/anaconda3/lib/python3.9/site-packages (from Jinja2>=2.10.1->Flask->dtale) (2.0.1)
# Collecting tenacity>=6.2.0
#   Downloading tenacity-8.0.1-py3-none-any.whl (24 kB)
# Collecting brotli
#   Downloading Brotli-1.0.9-cp39-cp39-macosx_10_9_x86_64.whl (421 kB)
#      |████████████████████████████████| 421 kB 1.1 MB/s eta 0:00:01
# Requirement already satisfied: python-dateutil>=2.7 in /Users/tarunsingh/opt/anaconda3/lib/python3.9/site-packages (from matplotlib->dtale) (2.8.2)
# Requirement already satisfied: kiwisolver>=1.0.1 in /Users/tarunsingh/opt/anaconda3/lib/python3.9/site-packages (from matplotlib->dtale) (1.3.1)
# Requirement already satisfied: pillow>=6.2.0 in /Users/tarunsingh/opt/anaconda3/lib/python3.9/site-packages (from matplotlib->dtale) (8.4.0)
# Requirement already satisfied: pyparsing>=2.2.1 in /Users/tarunsingh/opt/anaconda3/lib/python3.9/site-packages (from matplotlib->dtale) (3.0.4)
# Requirement already satisfied: pytz>=2017.3 in /Users/tarunsingh/opt/anaconda3/lib/python3.9/site-packages (from pandas->dtale) (2021.3)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /Users/tarunsingh/opt/anaconda3/lib/python3.9/site-packages (from requests->dtale) (1.26.7)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /Users/tarunsingh/opt/anaconda3/lib/python3.9/site-packages (from requests->dtale) (2.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/tarunsingh/opt/anaconda3/lib/python3.9/site-packages (from requests->dtale) (2021.10.8)
# Requirement already satisfied: idna<4,>=2.5 in /Users/tarunsingh/opt/anaconda3/lib/python3.9/site-packages (from requests->dtale) (3.2)
# Requirement already satisfied: patsy>=0.5 in /Users/tarunsingh/opt/anaconda3/lib/python3.9/site-packages (from statsmodels->dtale) (0.5.2)
# Requirement already satisfied: packaging>=20.0 in /Users/tarunsingh/opt/anaconda3/lib/python3.9/site-packages (from xarray->dtale) (21.0)
# Building wheels for collected packages: dash-core-components, dash-html-components, dash-table, dash-colorscales, dash-daq, ppscore
#   Building wheel for dash-core-components (setup.py) ... done
#   Created wheel for dash-core-components: filename=dash_core_components-2.0.0-py3-none-any.whl size=3821 sha256=aa20125a0701cc6828e5d36cc4f90bb5098a002876e2f25b9af2e75856282c89
#   Stored in directory: /Users/tarunsingh/Library/Caches/pip/wheels/2b/37/e9/4b5a8c878a47590de4dcf6bdc5a158788a1c17bea578a3ab60
#   Building wheel for dash-html-components (setup.py) ... done
#   Created wheel for dash-html-components: filename=dash_html_components-2.0.0-py3-none-any.whl size=4089 sha256=970e24397c1566c17a5985aef419846da0392520d1392dc7717cf87bd3a762cd
#   Stored in directory: /Users/tarunsingh/Library/Caches/pip/wheels/4d/22/3e/d58dc9820aeffc7b7193d04a63b08f585eef4a1ce836d69141
#   Building wheel for dash-table (setup.py) ... done
#   Created wheel for dash-table: filename=dash_table-5.0.0-py3-none-any.whl size=3911 sha256=ff5caa813574a201c36b5ad495ea1591b102d6953964704adf1c1988f7435922
#   Stored in directory: /Users/tarunsingh/Library/Caches/pip/wheels/1f/91/7e/015c42538da07aeb06576caca14da7c7416e9275a51fc85811
#   Building wheel for dash-colorscales (setup.py) ... done
#   Created wheel for dash-colorscales: filename=dash_colorscales-0.0.4-py3-none-any.whl size=62589 sha256=44e39fd4601ac0a66d0ce66cc2c8ac7877af90ab61294cfa94cfc0acc2b1b97d
#   Stored in directory: /Users/tarunsingh/Library/Caches/pip/wheels/ec/32/ec/dc8a1aa820182edf280a5e26c76fc9493ae29e196735708de2
#   Building wheel for dash-daq (setup.py) ... done
#   Created wheel for dash-daq: filename=dash_daq-0.5.0-py3-none-any.whl size=669716 sha256=6dbe57883b16b7568743f9b72f9c8b0c130ca9febbc7bca91e789bd25964911c
#   Stored in directory: /Users/tarunsingh/Library/Caches/pip/wheels/53/73/ea/8a422aab5cab848d88653ed3087c1fa05553c3fbd67fb6ab75
#   Building wheel for ppscore (setup.py) ... done
#   Created wheel for ppscore: filename=ppscore-1.2.0-py2.py3-none-any.whl size=13068 sha256=cb27409dd46f4972d9f34759b9958ccbe6ca54c05089a7c380004067490609e0
#   Stored in directory: /Users/tarunsingh/Library/Caches/pip/wheels/66/5f/af/a0de66f8359588661c0b1239580f4788dba33a4a1e504ef682
# Successfully built dash-core-components dash-html-components dash-table dash-colorscales dash-daq ppscore
# Installing collected packages: tenacity, brotli, plotly, Flask-Compress, dash-table, dash-html-components, dash-core-components, dash, xarray, strsimpy, squarify, ppscore, missingno, lz4, kaleido, flask-ngrok, dash-daq, dash-colorscales, dash-bootstrap-components, dtale
#   Attempting uninstall: missingno
#     Found existing installation: missingno 0.5.0
#     Uninstalling missingno-0.5.0:
#       Successfully uninstalled missingno-0.5.0
# Successfully installed Flask-Compress-1.10.1 brotli-1.0.9 dash-2.2.0 dash-bootstrap-components-1.0.3 dash-colorscales-0.0.4 dash-core-components-2.0.0 dash-daq-0.5.0 dash-html-components-2.0.0 dash-table-5.0.0 dtale-2.0.0 flask-ngrok-0.0.25 kaleido-0.2.1 lz4-4.0.0 missingno-0.4.2 plotly-5.6.0 ppscore-1.2.0 squarify-0.4.3 strsimpy-0.2.1 tenacity-8.0.1 xarray-0.21.1

# %%
import seaborn as sns

df3 = sns.load_dataset('titanic')
df3.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %%
import dtale
dtale.show(df3)
# Out:
#         <iframe
#             width="100%"
#             height="475"
#             src="http://Taruns-MacBook-Air.local:40000/dtale/iframe/3"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>

# %% [markdown]
# #### Automated EDA Libraries:
# 1. Dtale
# 2. Dataprep
# 3. Lux
# 4. Pandas Profiling
# 5. sweetviz
# 6. autoviz
# 7. Pandas Visual Analysis

# %%
# !pip install lux
# Out:
# Collecting lux
#   Downloading lux-0.8.2-py3-none-any.whl (354 kB)
#      |████████████████████████████████| 354 kB 410 kB/s eta 0:00:01
# Requirement already satisfied: greenlet in /Users/tarunsingh/opt/anaconda3/lib/python3.9/site-packages (from lux) (1.1.1)
# Requirement already satisfied: jinja2 in /Users/tarunsingh/opt/anaconda3/lib/python3.9/site-packages (from lux) (2.11.3)
# Requirement already satisfied: pyjwt in /Users/tarunsingh/opt/anaconda3/lib/python3.9/site-packages (from lux) (2.1.0)
# Requirement already satisfied: python-dateutil in /Users/tarunsingh/opt/anaconda3/lib/python3.9/site-packages (from lux) (2.8.2)
# Collecting pulsar-odm
#   Downloading pulsar-odm-0.7.0.tar.gz (40 kB)
#      |████████████████████████████████| 40 kB 915 kB/s eta 0:00:01
# Requirement already satisfied: pytz in /Users/tarunsingh/opt/anaconda3/lib/python3.9/site-packages (from lux) (2021.3)
# Requirement already satisfied: MarkupSafe>=0.23 in /Users/tarunsingh/opt/anaconda3/lib/python3.9/site-packages (from jinja2->lux) (2.0.1)
# Requirement already satisfied: sqlalchemy in /Users/tarunsingh/opt/anaconda3/lib/python3.9/site-packages (from pulsar-odm->lux) (1.4.22)
# Collecting psycopg2
#   Downloading psycopg2-2.9.3.tar.gz (380 kB)
#      |████████████████████████████████| 380 kB 2.2 MB/s eta 0:00:01
#     ERROR: Command errored out with exit status 1:
#      command: /Users/tarunsingh/opt/anaconda3/bin/python -c 'import io, os, sys, setuptools, tokenize; sys.argv[0] = '"'"'/private/var/folders/9k/dbx4wylx3hz1c7cj8tms5fkc0000gn/T/pip-install-46qc2s_s/psycopg2_77e112885ebc4492b3536c8b02aad436/setup.py'"'"'; __file__='"'"'/private/var/folders/9k/dbx4wylx3hz1c7cj8tms5fkc0000gn/T/pip-install-46qc2s_s/psycopg2_77e112885ebc4492b3536c8b02aad436/setup.py'"'"';f = getattr(tokenize, '"'"'open'"'"', open)(__file__) if os.path.exists(__file__) else io.StringIO('"'"'from setuptools import setup; setup()'"'"');code = f.read().replace('"'"'\r\n'"'"', '"'"'\n'"'"');f.close();exec(compile(code, __file__, '"'"'exec'"'"'))' egg_info --egg-base /private/var/folders/9k/dbx4wylx3hz1c7cj8tms5fkc0000gn/T/pip-pip-egg-info-baqavh6o
#          cwd: /private/var/folders/9k/dbx4wylx3hz1c7cj8tms5fkc0000gn/T/pip-install-46qc2s_s/psycopg2_77e112885ebc4492b3536c8b02aad436/
#     Complete output (23 lines):
#     running egg_info
#     creating /private/var/folders/9k/dbx4wylx3hz1c7cj8tms5fkc0000gn/T/pip-pip-egg-info-baqavh6o/psycopg2.egg-info
#     writing /private/var/folders/9k/dbx4wylx3hz1c7cj8tms5fkc0000gn/T/pip-pip-egg-info-baqavh6o/psycopg2.egg-info/PKG-INFO
#     writing dependency_links to /private/var/folders/9k/dbx4wylx3hz1c7cj8tms5fkc0000gn/T/pip-pip-egg-info-baqavh6o/psycopg2.egg-info/dependency_links.txt
#     writing top-level names to /private/var/folders/9k/dbx4wylx3hz1c7cj8tms5fkc0000gn/T/pip-pip-egg-info-baqavh6o/psycopg2.egg-info/top_level.txt
#     writing manifest file '/private/var/folders/9k/dbx4wylx3hz1c7cj8tms5fkc0000gn/T/pip-pip-egg-info-baqavh6o/psycopg2.egg-info/SOURCES.txt'
#
#     Error: pg_config executable not found.
#
#     pg_config is required to build psycopg2 from source.  Please add the directory
#     containing pg_config to the $PATH or specify the full executable path with the
#     option:
#
#         python setup.py build_ext --pg-config /path/to/pg_config build ...
#
#     or with the pg_config option in 'setup.cfg'.
#
#     If you prefer to avoid building psycopg2 from source, please install the PyPI
#     'psycopg2-binary' package instead.
#
#     For further information please check the 'doc/src/install.rst' file (also at
#     <https://www.psycopg.org/docs/install.html>).
#
#     ----------------------------------------
# WARNING: Discarding https://files.pythonhosted.org/packages/d1/1e/b450599a27b1809bccbd4e369f397cb18dc56b875778d961f9ae180b54b7/psycopg2-2.9.3.tar.gz#sha256=8e841d1bf3434da985cc5ef13e6f75c8981ced601fd70cc6bf33351b91562981 (from https://pypi.org/simple/psycopg2/) (requires-python:>=3.6). Command errored out with exit status 1: python setup.py egg_info Check the logs for full command output.
#   Downloading psycopg2-2.9.2.tar.gz (380 kB)
#      |████████████████████████████████| 380 kB 3.5 MB/s eta 0:00:01
#     ERROR: Command errored out with exit status 1:
#      command: /Users/tarunsingh/opt/anaconda3/bin/python -c 'import io, os, sys, setuptools, tokenize; sys.argv[0] = '"'"'/private/var/folders/9k/dbx4wylx3hz1c7cj8tms5fkc0000gn/T/pip-install-46qc2s_s/psycopg2_278c2104825c451c8e1dd320979313c5/setup.py'"'"'; __file__='"'"'/private/var/folders/9k/dbx4wylx3hz1c7cj8tms5fkc0000gn/T/pip-install-46qc2s_s/psycopg2_278c2104825c451c8e1dd320979313c5/setup.py'"'"';f = getattr(tokenize, '"'"'open'"'"', open)(__file__) if os.path.exists(__file__) else io.StringIO('"'"'from setuptools import setup; setup()'"'"');code = f.read().replace('"'"'\r\n'"'"', '"'"'\n'"'"');f.close();exec(compile(code, __file__, '"'"'exec'"'"'))' egg_info --egg-base /private/var/folders/9k/dbx4wylx3hz1c7cj8tms5fkc0000gn/T/pip-pip-egg-info-7z5d8h30
#          cwd: /private/var/folders/9k/dbx4wylx3hz1c7cj8tms5fkc0000gn/T/pip-install-46qc2s_s/psycopg2_278c2104825c451c8e1dd320979313c5/
#     Complete output (23 lines):
#     running egg_info
#     creating /private/var/folders/9k/dbx4wylx3hz1c7cj8tms5fkc0000gn/T/pip-pip-egg-info-7z5d8h30/psycopg2.egg-info
#     writing /private/var/folders/9k/dbx4wylx3hz1c7cj8tms5fkc0000gn/T/pip-pip-egg-info-7z5d8h30/psycopg2.egg-info/PKG-INFO
#     writing dependency_links to /private/var/folders/9k/dbx4wylx3hz1c7cj8tms5fkc0000gn/T/pip-pip-egg-info-7z5d8h30/psycopg2.egg-info/dependency_links.txt
#     writing top-level names to /private/var/folders/9k/dbx4wylx3hz1c7cj8tms5fkc0000gn/T/pip-pip-egg-info-7z5d8h30/psycopg2.egg-info/top_level.txt
#     writing manifest file '/private/var/folders/9k/dbx4wylx3hz1c7cj8tms5fkc0000gn/T/pip-pip-egg-info-7z5d8h30/psycopg2.egg-info/SOURCES.txt'
#
#     Error: pg_config executable not found.
#
#     pg_config is required to build psycopg2 from source.  Please add the directory
#     containing pg_config to the $PATH or specify the full executable path with the
#     option:
#
#         python setup.py build_ext --pg-config /path/to/pg_config build ...
#
#     or with the pg_config option in 'setup.cfg'.
#
#     If you prefer to avoid building psycopg2 from source, please install the PyPI
#     'psycopg2-binary' package instead.
#
#     For further information please check the 'doc/src/install.rst' file (also at
#     <https://www.psycopg.org/docs/install.html>).
#
#     ----------------------------------------
# WARNING: Discarding https://files.pythonhosted.org/packages/33/ed/79434011d773e5ea4c51262f6ebfb86680c2908d7677f31ebccd5aa9f1b3/psycopg2-2.9.2.tar.gz#sha256=a84da9fa891848e0270e8e04dcca073bc9046441eeb47069f5c0e36783debbea (from https://pypi.org/simple/psycopg2/) (requires-python:>=3.6). Command errored out with exit status 1: python setup.py egg_info Check the logs for full command output.
#   Downloading psycopg2-2.9.1.tar.gz (379 kB)
#      |████████████████████████████████| 379 kB 1.4 MB/s eta 0:00:01
#     ERROR: Command errored out with exit status 1:
#      command: /Users/tarunsingh/opt/anaconda3/bin/python -c 'import io, os, sys, setuptools, tokenize; sys.argv[0] = '"'"'/private/var/folders/9k/dbx4wylx3hz1c7cj8tms5fkc0000gn/T/pip-install-46qc2s_s/psycopg2_0037034c27194aa7a41a3167d1595876/setup.py'"'"'; __file__='"'"'/private/var/folders/9k/dbx4wylx3hz1c7cj8tms5fkc0000gn/T/pip-install-46qc2s_s/psycopg2_0037034c27194aa7a41a3167d1595876/setup.py'"'"';f = getattr(tokenize, '"'"'open'"'"', open)(__file__) if os.path.exists(__file__) else io.StringIO('"'"'from setuptools import setup; setup()'"'"');code = f.read().replace('"'"'\r\n'"'"', '"'"'\n'"'"');f.close();exec(compile(code, __file__, '"'"'exec'"'"'))' egg_info --egg-base /private/var/folders/9k/dbx4wylx3hz1c7cj8tms5fkc0000gn/T/pip-pip-egg-info-kcvchgde
#          cwd: /private/var/folders/9k/dbx4wylx3hz1c7cj8tms5fkc0000gn/T/pip-install-46qc2s_s/psycopg2_0037034c27194aa7a41a3167d1595876/
#     Complete output (23 lines):
#     running egg_info
#     creating /private/var/folders/9k/dbx4wylx3hz1c7cj8tms5fkc0000gn/T/pip-pip-egg-info-kcvchgde/psycopg2.egg-info
#     writing /private/var/folders/9k/dbx4wylx3hz1c7cj8tms5fkc0000gn/T/pip-pip-egg-info-kcvchgde/psycopg2.egg-info/PKG-INFO
#     writing dependency_links to /private/var/folders/9k/dbx4wylx3hz1c7cj8tms5fkc0000gn/T/pip-pip-egg-info-kcvchgde/psycopg2.egg-info/dependency_links.txt
#     writing top-level names to /private/var/folders/9k/dbx4wylx3hz1c7cj8tms5fkc0000gn/T/pip-pip-egg-info-kcvchgde/psycopg2.egg-info/top_level.txt
#     writing manifest file '/private/var/folders/9k/dbx4wylx3hz1c7cj8tms5fkc0000gn/T/pip-pip-egg-info-kcvchgde/psycopg2.egg-info/SOURCES.txt'
#
#     Error: pg_config executable not found.
#
#     pg_config is required to build psycopg2 from source.  Please add the directory
#     containing pg_config to the $PATH or specify the full executable path with the
#     option:
#
#         python setup.py build_ext --pg-config /path/to/pg_config build ...
#
#     or with the pg_config option in 'setup.cfg'.
#
#     If you prefer to avoid building psycopg2 from source, please install the PyPI
#     'psycopg2-binary' package instead.
#
#     For further information please check the 'doc/src/install.rst' file (also at
#     <https://www.psycopg.org/docs/install.html>).
#
#     ----------------------------------------
# WARNING: Discarding https://files.pythonhosted.org/packages/aa/8a/7c80e7e44fb1b4277e89bd9ca509aefdd4dd1b2c547c6f293afe9f7ffd04/psycopg2-2.9.1.tar.gz#sha256=de5303a6f1d0a7a34b9d40e4d3bef684ccc44a49bbe3eb85e3c0bffb4a131b7c (from https://pypi.org/simple/psycopg2/) (requires-python:>=3.6). Command errored out with exit status 1: python setup.py egg_info Check the logs for full command output.
#   Downloading psycopg2-2.9.tar.gz (379 kB)
#      |████████████████████████████████| 379 kB 1.3 MB/s eta 0:00:01
#     ERROR: Command errored out with exit status 1:
#      command: /Users/tarunsingh/opt/anaconda3/bin/python -c 'import io, os, sys, setuptools, tokenize; sys.argv[0] = '"'"'/private/var/folders/9k/dbx4wylx3hz1c7cj8tms5fkc0000gn/T/pip-install-46qc2s_s/psycopg2_f5d42c8522654a53a3dee0c8405f721c/setup.py'"'"'; __file__='"'"'/private/var/folders/9k/dbx4wylx3hz1c7cj8tms5fkc0000gn/T/pip-install-46qc2s_s/psycopg2_f5d42c8522654a53a3dee0c8405f721c/setup.py'"'"';f = getattr(tokenize, '"'"'open'"'"', open)(__file__) if os.path.exists(__file__) else io.StringIO('"'"'from setuptools import setup; setup()'"'"');code = f.read().replace('"'"'\r\n'"'"', '"'"'\n'"'"');f.close();exec(compile(code, __file__, '"'"'exec'"'"'))' egg_info --egg-base /private/var/folders/9k/dbx4wylx3hz1c7cj8tms5fkc0000gn/T/pip-pip-egg-info-sc539ay4
#          cwd: /private/var/folders/9k/dbx4wylx3hz1c7cj8tms5fkc0000gn/T/pip-install-46qc2s_s/psycopg2_f5d42c8522654a53a3dee0c8405f721c/
#     Complete output (23 lines):
#     running egg_info
#     creating /private/var/folders/9k/dbx4wylx3hz1c7cj8tms5fkc0000gn/T/pip-pip-egg-info-sc539ay4/psycopg2.egg-info
#     writing /private/var/folders/9k/dbx4wylx3hz1c7cj8tms5fkc0000gn/T/pip-pip-egg-info-sc539ay4/psycopg2.egg-info/PKG-INFO
#     writing dependency_links to /private/var/folders/9k/dbx4wylx3hz1c7cj8tms5fkc0000gn/T/pip-pip-egg-info-sc539ay4/psycopg2.egg-info/dependency_links.txt
#     writing top-level names to /private/var/folders/9k/dbx4wylx3hz1c7cj8tms5fkc0000gn/T/pip-pip-egg-info-sc539ay4/psycopg2.egg-info/top_level.txt
#     writing manifest file '/private/var/folders/9k/dbx4wylx3hz1c7cj8tms5fkc0000gn/T/pip-pip-egg-info-sc539ay4/psycopg2.egg-info/SOURCES.txt'
#
#     Error: pg_config executable not found.
#
#     pg_config is required to build psycopg2 from source.  Please add the directory
#     containing pg_config to the $PATH or specify the full executable path with the
#     option:
#
#         python setup.py build_ext --pg-config /path/to/pg_config build ...
#
#     or with the pg_config option in 'setup.cfg'.
#
#     If you prefer to avoid building psycopg2 from source, please install the PyPI
#     'psycopg2-binary' package instead.
#
#     For further information please check the 'doc/src/install.rst' file (also at
#     <https://www.psycopg.org/docs/install.html>).
#
#     ----------------------------------------
# WARNING: Discarding https://files.pythonhosted.org/packages/6c/79/6df8af2405e2aa60732c47757453fc7fa4af5c90a1796b3392ef892d3a52/psycopg2-2.9.tar.gz#sha256=b12073fdf2002e828e5921be2c39ff9c6eab361c5c0bd6c529619fc23677accc (from https://pypi.org/simple/psycopg2/) (requires-python:>=3.6). Command errored out with exit status 1: python setup.py egg_info Check the logs for full command output.
#   Downloading psycopg2-2.8.6.tar.gz (383 kB)
#      |████████████████████████████████| 383 kB 1.6 MB/s eta 0:00:01
#     ERROR: Command errored out with exit status 1:
#      command: /Users/tarunsingh/opt/anaconda3/bin/python -c 'import io, os, sys, setuptools, tokenize; sys.argv[0] = '"'"'/private/var/folders/9k/dbx4wylx3hz1c7cj8tms5fkc0000gn/T/pip-install-46qc2s_s/psycopg2_d26ce6bf00104ac88765f2b24bc2ad25/setup.py'"'"'; __file__='"'"'/private/var/folders/9k/dbx4wylx3hz1c7cj8tms5fkc0000gn/T/pip-install-46qc2s_s/psycopg2_d26ce6bf00104ac88765f2b24bc2ad25/setup.py'"'"';f = getattr(tokenize, '"'"'open'"'"', open)(__file__) if os.path.exists(__file__) else io.StringIO('"'"'from setuptools import setup; setup()'"'"');code = f.read().replace('"'"'\r\n'"'"', '"'"'\n'"'"');f.close();exec(compile(code, __file__, '"'"'exec'"'"'))' egg_info --egg-base /private/var/folders/9k/dbx4wylx3hz1c7cj8tms5fkc0000gn/T/pip-pip-egg-info-xptja67_
#          cwd: /private/var/folders/9k/dbx4wylx3hz1c7cj8tms5fkc0000gn/T/pip-install-46qc2s_s/psycopg2_d26ce6bf00104ac88765f2b24bc2ad25/
#     Complete output (23 lines):
#     running egg_info
#     creating /private/var/folders/9k/dbx4wylx3hz1c7cj8tms5fkc0000gn/T/pip-pip-egg-info-xptja67_/psycopg2.egg-info
#     writing /private/var/folders/9k/dbx4wylx3hz1c7cj8tms5fkc0000gn/T/pip-pip-egg-info-xptja67_/psycopg2.egg-info/PKG-INFO
#     writing dependency_links to /private/var/folders/9k/dbx4wylx3hz1c7cj8tms5fkc0000gn/T/pip-pip-egg-info-xptja67_/psycopg2.egg-info/dependency_links.txt
#     writing top-level names to /private/var/folders/9k/dbx4wylx3hz1c7cj8tms5fkc0000gn/T/pip-pip-egg-info-xptja67_/psycopg2.egg-info/top_level.txt
#     writing manifest file '/private/var/folders/9k/dbx4wylx3hz1c7cj8tms5fkc0000gn/T/pip-pip-egg-info-xptja67_/psycopg2.egg-info/SOURCES.txt'
#
#     Error: pg_config executable not found.
#
#     pg_config is required to build psycopg2 from source.  Please add the directory
#     containing pg_config to the $PATH or specify the full executable path with the
#     option:
#
#         python setup.py build_ext --pg-config /path/to/pg_config build ...
#
#     or with the pg_config option in 'setup.cfg'.
#
#     If you prefer to avoid building psycopg2 from source, please install the PyPI
#     'psycopg2-binary' package instead.
#
#     For further information please check the 'doc/src/install.rst' file (also at
#     <https://www.psycopg.org/docs/install.html>).
#
#     ----------------------------------------
# WARNING: Discarding https://files.pythonhosted.org/packages/fd/ae/98cb7a0cbb1d748ee547b058b14604bd0e9bf285a8e0cc5d148f8a8a952e/psycopg2-2.8.6.tar.gz#sha256=fb23f6c71107c37fd667cb4ea363ddeb936b348bbd6449278eb92c189699f543 (from https://pypi.org/simple/psycopg2/) (requires-python:>=2.7,!=3.0.*,!=3.1.*,!=3.2.*,!=3.3.*). Command errored out with exit status 1: python setup.py egg_info Check the logs for full command output.
#   Downloading psycopg2-2.8.5.tar.gz (380 kB)
#      |████████████████████████████████| 380 kB 1.4 MB/s eta 0:00:01
#     ERROR: Command errored out with exit status 1:
#      command: /Users/tarunsingh/opt/anaconda3/bin/python -c 'import io, os, sys, setuptools, tokenize; sys.argv[0] = '"'"'/private/var/folders/9k/dbx4wylx3hz1c7cj8tms5fkc0000gn/T/pip-install-46qc2s_s/psycopg2_2eb3aee046c24ddda80028ff599bd2a2/setup.py'"'"'; __file__='"'"'/private/var/folders/9k/dbx4wylx3hz1c7cj8tms5fkc0000gn/T/pip-install-46qc2s_s/psycopg2_2eb3aee046c24ddda80028ff599bd2a2/setup.py'"'"';f = getattr(tokenize, '"'"'open'"'"', open)(__file__) if os.path.exists(__file__) else io.StringIO('"'"'from setuptools import setup; setup()'"'"');code = f.read().replace('"'"'\r\n'"'"', '"'"'\n'"'"');f.close();exec(compile(code, __file__, '"'"'exec'"'"'))' egg_info --egg-base /private/var/folders/9k/dbx4wylx3hz1c7cj8tms5fkc0000gn/T/pip-pip-egg-info-selq4zt1
#          cwd: /private/var/folders/9k/dbx4wylx3hz1c7cj8tms5fkc0000gn/T/pip-install-46qc2s_s/psycopg2_2eb3aee046c24ddda80028ff599bd2a2/
#     Complete output (23 lines):
#     running egg_info
#     creating /private/var/folders/9k/dbx4wylx3hz1c7cj8tms5fkc0000gn/T/pip-pip-egg-info-selq4zt1/psycopg2.egg-info
#     writing /private/var/folders/9k/dbx4wylx3hz1c7cj8tms5fkc0000gn/T/pip-pip-egg-info-selq4zt1/psycopg2.egg-info/PKG-INFO
#     writing dependency_links to /private/var/folders/9k/dbx4wylx3hz1c7cj8tms5fkc0000gn/T/pip-pip-egg-info-selq4zt1/psycopg2.egg-info/dependency_links.txt
#     writing top-level names to /private/var/folders/9k/dbx4wylx3hz1c7cj8tms5fkc0000gn/T/pip-pip-egg-info-selq4zt1/psycopg2.egg-info/top_level.txt
#     writing manifest file '/private/var/folders/9k/dbx4wylx3hz1c7cj8tms5fkc0000gn/T/pip-pip-egg-info-selq4zt1/psycopg2.egg-info/SOURCES.txt'
#
#     Error: pg_config executable not found.
#
#     pg_config is required to build psycopg2 from source.  Please add the directory
#     containing pg_config to the $PATH or specify the full executable path with the
#     option:
#
#         python setup.py build_ext --pg-config /path/to/pg_config build ...
#
#     or with the pg_config option in 'setup.cfg'.
#
#     If you prefer to avoid building psycopg2 from source, please install the PyPI
#     'psycopg2-binary' package instead.
#
#     For further information please check the 'doc/src/install.rst' file (also at
#     <https://www.psycopg.org/docs/install.html>).
#
#     ----------------------------------------
# WARNING: Discarding https://files.pythonhosted.org/packages/a8/8f/1c5690eebf148d1d1554fc00ccf9101e134636553dbb75bdfef4f85d7647/psycopg2-2.8.5.tar.gz#sha256=f7d46240f7a1ae1dd95aab38bd74f7428d46531f69219954266d669da60c0818 (from https://pypi.org/simple/psycopg2/) (requires-python:>=2.7,!=3.0.*,!=3.1.*,!=3.2.*,!=3.3.*). Command errored out with exit status 1: python setup.py egg_info Check the logs for full command output.
#   Downloading psycopg2-2.8.4.tar.gz (377 kB)
#      |████████████████████████████████| 377 kB 2.8 MB/s eta 0:00:01
#     ERROR: Command errored out with exit status 1:
#      command: /Users/tarunsingh/opt/anaconda3/bin/python -c 'import io, os, sys, setuptools, tokenize; sys.argv[0] = '"'"'/private/var/folders/9k/dbx4wylx3hz1c7cj8tms5fkc0000gn/T/pip-install-46qc2s_s/psycopg2_2225a2fb7f8e4902aca0bf4407dfa873/setup.py'"'"'; __file__='"'"'/private/var/folders/9k/dbx4wylx3hz1c7cj8tms5fkc0000gn/T/pip-install-46qc2s_s/psycopg2_2225a2fb7f8e4902aca0bf4407dfa873/setup.py'"'"';f = getattr(tokenize, '"'"'open'"'"', open)(__file__) if os.path.exists(__file__) else io.StringIO('"'"'from setuptools import setup; setup()'"'"');code = f.read().replace('"'"'\r\n'"'"', '"'"'\n'"'"');f.close();exec(compile(code, __file__, '"'"'exec'"'"'))' egg_info --egg-base /private/var/folders/9k/dbx4wylx3hz1c7cj8tms5fkc0000gn/T/pip-pip-egg-info-ka7onziz
#          cwd: /private/var/folders/9k/dbx4wylx3hz1c7cj8tms5fkc0000gn/T/pip-install-46qc2s_s/psycopg2_2225a2fb7f8e4902aca0bf4407dfa873/
#     Complete output (23 lines):
#     running egg_info
#     creating /private/var/folders/9k/dbx4wylx3hz1c7cj8tms5fkc0000gn/T/pip-pip-egg-info-ka7onziz/psycopg2.egg-info
#     writing /private/var/folders/9k/dbx4wylx3hz1c7cj8tms5fkc0000gn/T/pip-pip-egg-info-ka7onziz/psycopg2.egg-info/PKG-INFO
#     writing dependency_links to /private/var/folders/9k/dbx4wylx3hz1c7cj8tms5fkc0000gn/T/pip-pip-egg-info-ka7onziz/psycopg2.egg-info/dependency_links.txt
#     writing top-level names to /private/var/folders/9k/dbx4wylx3hz1c7cj8tms5fkc0000gn/T/pip-pip-egg-info-ka7onziz/psycopg2.egg-info/top_level.txt
#     writing manifest file '/private/var/folders/9k/dbx4wylx3hz1c7cj8tms5fkc0000gn/T/pip-pip-egg-info-ka7onziz/psycopg2.egg-info/SOURCES.txt'
#
#     Error: pg_config executable not found.
#
#     pg_config is required to build psycopg2 from source.  Please add the directory
#     containing pg_config to the $PATH or specify the full executable path with the
#     option:
#
#         python setup.py build_ext --pg-config /path/to/pg_config build ...
#
#     or with the pg_config option in 'setup.cfg'.
#
#     If you prefer to avoid building psycopg2 from source, please install the PyPI
#     'psycopg2-binary' package instead.
#
#     For further information please check the 'doc/src/install.rst' file (also at
#     <http://initd.org/psycopg/docs/install.html>).
#
#     ----------------------------------------
# WARNING: Discarding https://files.pythonhosted.org/packages/84/d7/6a93c99b5ba4d4d22daa3928b983cec66df4536ca50b22ce5dcac65e4e71/psycopg2-2.8.4.tar.gz#sha256=f898e5cc0a662a9e12bde6f931263a1bbd350cfb18e1d5336a12927851825bb6 (from https://pypi.org/simple/psycopg2/) (requires-python:>=2.7,!=3.0.*,!=3.1.*,!=3.2.*,!=3.3.*). Command errored out with exit status 1: python setup.py egg_info Check the logs for full command output.
#   Downloading psycopg2-2.8.3.tar.gz (377 kB)
#      |████████████████████████████████| 377 kB 1.6 MB/s eta 0:00:01
#     ERROR: Command errored out with exit status 1:
#      command: /Users/tarunsingh/opt/anaconda3/bin/python -c 'import io, os, sys, setuptools, tokenize; sys.argv[0] = '"'"'/private/var/folders/9k/dbx4wylx3hz1c7cj8tms5fkc0000gn/T/pip-install-46qc2s_s/psycopg2_852179860bcf4aeda6a6d2e883bd9ef5/setup.py'"'"'; __file__='"'"'/private/var/folders/9k/dbx4wylx3hz1c7cj8tms5fkc0000gn/T/pip-install-46qc2s_s/psycopg2_852179860bcf4aeda6a6d2e883bd9ef5/setup.py'"'"';f = getattr(tokenize, '"'"'open'"'"', open)(__file__) if os.path.exists(__file__) else io.StringIO('"'"'from setuptools import setup; setup()'"'"');code = f.read().replace('"'"'\r\n'"'"', '"'"'\n'"'"');f.close();exec(compile(code, __file__, '"'"'exec'"'"'))' egg_info --egg-base /private/var/folders/9k/dbx4wylx3hz1c7cj8tms5fkc0000gn/T/pip-pip-egg-info-l5dqkta0
#          cwd: /private/var/folders/9k/dbx4wylx3hz1c7cj8tms5fkc0000gn/T/pip-install-46qc2s_s/psycopg2_852179860bcf4aeda6a6d2e883bd9ef5/
#     Complete output (23 lines):
#     running egg_info
#     creating /private/var/folders/9k/dbx4wylx3hz1c7cj8tms5fkc0000gn/T/pip-pip-egg-info-l5dqkta0/psycopg2.egg-info
#     writing /private/var/folders/9k/dbx4wylx3hz1c7cj8tms5fkc0000gn/T/pip-pip-egg-info-l5dqkta0/psycopg2.egg-info/PKG-INFO
#     writing dependency_links to /private/var/folders/9k/dbx4wylx3hz1c7cj8tms5fkc0000gn/T/pip-pip-egg-info-l5dqkta0/psycopg2.egg-info/dependency_links.txt
#     writing top-level names to /private/var/folders/9k/dbx4wylx3hz1c7cj8tms5fkc0000gn/T/pip-pip-egg-info-l5dqkta0/psycopg2.egg-info/top_level.txt
#     writing manifest file '/private/var/folders/9k/dbx4wylx3hz1c7cj8tms5fkc0000gn/T/pip-pip-egg-info-l5dqkta0/psycopg2.egg-info/SOURCES.txt'
#
#     Error: pg_config executable not found.
#
#     pg_config is required to build psycopg2 from source.  Please add the directory
#     containing pg_config to the $PATH or specify the full executable path with the
#     option:
#
#         python setup.py build_ext --pg-config /path/to/pg_config build ...
#
#     or with the pg_config option in 'setup.cfg'.
#
#     If you prefer to avoid building psycopg2 from source, please install the PyPI
#     'psycopg2-binary' package instead.
#
#     For further information please check the 'doc/src/install.rst' file (also at
#     <http://initd.org/psycopg/docs/install.html>).
#
#     ----------------------------------------
# WARNING: Discarding https://files.pythonhosted.org/packages/5c/1c/6997288da181277a0c29bc39a5f9143ff20b8c99f2a7d059cfb55163e165/psycopg2-2.8.3.tar.gz#sha256=897a6e838319b4bf648a574afb6cabcb17d0488f8c7195100d48d872419f4457 (from https://pypi.org/simple/psycopg2/) (requires-python:>=2.7,!=3.0.*,!=3.1.*,!=3.2.*,!=3.3.*). Command errored out with exit status 1: python setup.py egg_info Check the logs for full command output.
#   Downloading psycopg2-2.8.2.tar.gz (368 kB)
#      |████████████████████████████████| 368 kB 1.1 MB/s eta 0:00:01
#     ERROR: Command errored out with exit status 1:
#      command: /Users/tarunsingh/opt/anaconda3/bin/python -c 'import io, os, sys, setuptools, tokenize; sys.argv[0] = '"'"'/private/var/folders/9k/dbx4wylx3hz1c7cj8tms5fkc0000gn/T/pip-install-46qc2s_s/psycopg2_c81a5971dd7542b2aececb836a17f968/setup.py'"'"'; __file__='"'"'/private/var/folders/9k/dbx4wylx3hz1c7cj8tms5fkc0000gn/T/pip-install-46qc2s_s/psycopg2_c81a5971dd7542b2aececb836a17f968/setup.py'"'"';f = getattr(tokenize, '"'"'open'"'"', open)(__file__) if os.path.exists(__file__) else io.StringIO('"'"'from setuptools import setup; setup()'"'"');code = f.read().replace('"'"'\r\n'"'"', '"'"'\n'"'"');f.close();exec(compile(code, __file__, '"'"'exec'"'"'))' egg_info --egg-base /private/var/folders/9k/dbx4wylx3hz1c7cj8tms5fkc0000gn/T/pip-pip-egg-info-myds3wrw
#          cwd: /private/var/folders/9k/dbx4wylx3hz1c7cj8tms5fkc0000gn/T/pip-install-46qc2s_s/psycopg2_c81a5971dd7542b2aececb836a17f968/
#     Complete output (23 lines):
#     running egg_info
#     creating /private/var/folders/9k/dbx4wylx3hz1c7cj8tms5fkc0000gn/T/pip-pip-egg-info-myds3wrw/psycopg2.egg-info
#     writing /private/var/folders/9k/dbx4wylx3hz1c7cj8tms5fkc0000gn/T/pip-pip-egg-info-myds3wrw/psycopg2.egg-info/PKG-INFO
#     writing dependency_links to /private/var/folders/9k/dbx4wylx3hz1c7cj8tms5fkc0000gn/T/pip-pip-egg-info-myds3wrw/psycopg2.egg-info/dependency_links.txt
#     writing top-level names to /private/var/folders/9k/dbx4wylx3hz1c7cj8tms5fkc0000gn/T/pip-pip-egg-info-myds3wrw/psycopg2.egg-info/top_level.txt
#     writing manifest file '/private/var/folders/9k/dbx4wylx3hz1c7cj8tms5fkc0000gn/T/pip-pip-egg-info-myds3wrw/psycopg2.egg-info/SOURCES.txt'
#
#     Error: pg_config executable not found.
#
#     pg_config is required to build psycopg2 from source.  Please add the directory
#     containing pg_config to the $PATH or specify the full executable path with the
#     option:
#
#         python setup.py build_ext --pg-config /path/to/pg_config build ...
#
#     or with the pg_config option in 'setup.cfg'.
#
#     If you prefer to avoid building psycopg2 from source, please install the PyPI
#     'psycopg2-binary' package instead.
#
#     For further information please check the 'doc/src/install.rst' file (also at
#     <http://initd.org/psycopg/docs/install.html>).
#
#     ----------------------------------------
# WARNING: Discarding https://files.pythonhosted.org/packages/23/7e/93c325482c328619870b6cd09370f6dbe1148283daca65115cd63642e60f/psycopg2-2.8.2.tar.gz#sha256=5cacf21b6f813c239f100ef78a4132056f93a5940219ec25d2ef833cbeb05588 (from https://pypi.org/simple/psycopg2/) (requires-python:>=2.7,!=3.0.*,!=3.1.*,!=3.2.*,!=3.3.*). Command errored out with exit status 1: python setup.py egg_info Check the logs for full command output.
#   Downloading psycopg2-2.8.1.tar.gz (367 kB)
#      |████████████████████████████████| 367 kB 1.2 MB/s eta 0:00:01
#     ERROR: Command errored out with exit status 1:
#      command: /Users/tarunsingh/opt/anaconda3/bin/python -c 'import io, os, sys, setuptools, tokenize; sys.argv[0] = '"'"'/private/var/folders/9k/dbx4wylx3hz1c7cj8tms5fkc0000gn/T/pip-install-46qc2s_s/psycopg2_91aa00ee8217480ea791474fbf5637f9/setup.py'"'"'; __file__='"'"'/private/var/folders/9k/dbx4wylx3hz1c7cj8tms5fkc0000gn/T/pip-install-46qc2s_s/psycopg2_91aa00ee8217480ea791474fbf5637f9/setup.py'"'"';f = getattr(tokenize, '"'"'open'"'"', open)(__file__) if os.path.exists(__file__) else io.StringIO('"'"'from setuptools import setup; setup()'"'"');code = f.read().replace('"'"'\r\n'"'"', '"'"'\n'"'"');f.close();exec(compile(code, __file__, '"'"'exec'"'"'))' egg_info --egg-base /private/var/folders/9k/dbx4wylx3hz1c7cj8tms5fkc0000gn/T/pip-pip-egg-info-q7mx9ezz
#          cwd: /private/var/folders/9k/dbx4wylx3hz1c7cj8tms5fkc0000gn/T/pip-install-46qc2s_s/psycopg2_91aa00ee8217480ea791474fbf5637f9/
#     Complete output (23 lines):
#     running egg_info
#     creating /private/var/folders/9k/dbx4wylx3hz1c7cj8tms5fkc0000gn/T/pip-pip-egg-info-q7mx9ezz/psycopg2.egg-info
#     writing /private/var/folders/9k/dbx4wylx3hz1c7cj8tms5fkc0000gn/T/pip-pip-egg-info-q7mx9ezz/psycopg2.egg-info/PKG-INFO
#     writing dependency_links to /private/var/folders/9k/dbx4wylx3hz1c7cj8tms5fkc0000gn/T/pip-pip-egg-info-q7mx9ezz/psycopg2.egg-info/dependency_links.txt
#     writing top-level names to /private/var/folders/9k/dbx4wylx3hz1c7cj8tms5fkc0000gn/T/pip-pip-egg-info-q7mx9ezz/psycopg2.egg-info/top_level.txt
#     writing manifest file '/private/var/folders/9k/dbx4wylx3hz1c7cj8tms5fkc0000gn/T/pip-pip-egg-info-q7mx9ezz/psycopg2.egg-info/SOURCES.txt'
#
#     Error: pg_config executable not found.
#
#     pg_config is required to build psycopg2 from source.  Please add the directory
#     containing pg_config to the $PATH or specify the full executable path with the
#     option:
#
#         python setup.py build_ext --pg-config /path/to/pg_config build ...
#
#     or with the pg_config option in 'setup.cfg'.
#
#     If you prefer to avoid building psycopg2 from source, please install the PyPI
#     'psycopg2-binary' package instead.
#
#     For further information please check the 'doc/src/install.rst' file (also at
#     <http://initd.org/psycopg/docs/install.html>).
#
#     ----------------------------------------
# WARNING: Discarding https://files.pythonhosted.org/packages/52/be/f898e712f5f08131d651a62754fca82a1deb42e4e9889ad01932f770a2be/psycopg2-2.8.1.tar.gz#sha256=b4a475ce87eabc0607e068a3c704d0aa0820237ed78d493b8e2d880eb73cd7fe (from https://pypi.org/simple/psycopg2/) (requires-python:>=2.7,!=3.0.*,!=3.1.*,!=3.2.*,!=3.3.*). Command errored out with exit status 1: python setup.py egg_info Check the logs for full command output.
#   Downloading psycopg2-2.8.tar.gz (367 kB)
#      |████████████████████████████████| 367 kB 1.1 MB/s eta 0:00:01
#     ERROR: Command errored out with exit status 1:
#      command: /Users/tarunsingh/opt/anaconda3/bin/python -c 'import io, os, sys, setuptools, tokenize; sys.argv[0] = '"'"'/private/var/folders/9k/dbx4wylx3hz1c7cj8tms5fkc0000gn/T/pip-install-46qc2s_s/psycopg2_22471567bd8949ab8650df310344c54f/setup.py'"'"'; __file__='"'"'/private/var/folders/9k/dbx4wylx3hz1c7cj8tms5fkc0000gn/T/pip-install-46qc2s_s/psycopg2_22471567bd8949ab8650df310344c54f/setup.py'"'"';f = getattr(tokenize, '"'"'open'"'"', open)(__file__) if os.path.exists(__file__) else io.StringIO('"'"'from setuptools import setup; setup()'"'"');code = f.read().replace('"'"'\r\n'"'"', '"'"'\n'"'"');f.close();exec(compile(code, __file__, '"'"'exec'"'"'))' egg_info --egg-base /private/var/folders/9k/dbx4wylx3hz1c7cj8tms5fkc0000gn/T/pip-pip-egg-info-qz8_6vi_
#          cwd: /private/var/folders/9k/dbx4wylx3hz1c7cj8tms5fkc0000gn/T/pip-install-46qc2s_s/psycopg2_22471567bd8949ab8650df310344c54f/
#     Complete output (23 lines):
#     running egg_info
#     creating /private/var/folders/9k/dbx4wylx3hz1c7cj8tms5fkc0000gn/T/pip-pip-egg-info-qz8_6vi_/psycopg2.egg-info
#     writing /private/var/folders/9k/dbx4wylx3hz1c7cj8tms5fkc0000gn/T/pip-pip-egg-info-qz8_6vi_/psycopg2.egg-info/PKG-INFO
#     writing dependency_links to /private/var/folders/9k/dbx4wylx3hz1c7cj8tms5fkc0000gn/T/pip-pip-egg-info-qz8_6vi_/psycopg2.egg-info/dependency_links.txt
#     writing top-level names to /private/var/folders/9k/dbx4wylx3hz1c7cj8tms5fkc0000gn/T/pip-pip-egg-info-qz8_6vi_/psycopg2.egg-info/top_level.txt
#     writing manifest file '/private/var/folders/9k/dbx4wylx3hz1c7cj8tms5fkc0000gn/T/pip-pip-egg-info-qz8_6vi_/psycopg2.egg-info/SOURCES.txt'
#
#     Error: pg_config executable not found.
#
#     pg_config is required to build psycopg2 from source.  Please add the directory
#     containing pg_config to the $PATH or specify the full executable path with the
#     option:
#
#         python setup.py build_ext --pg-config /path/to/pg_config build ...
#
#     or with the pg_config option in 'setup.cfg'.
#
#     If you prefer to avoid building psycopg2 from source, please install the PyPI
#     'psycopg2-binary' package instead.
#
#     For further information please check the 'doc/src/install.rst' file (also at
#     <http://initd.org/psycopg/docs/install.html>).
#
#     ----------------------------------------
# WARNING: Discarding https://files.pythonhosted.org/packages/c7/ca/75236b17f1b951950ffc55d657c5aa408d3d0327a1b6c4c0f7cb16ef7e7b/psycopg2-2.8.tar.gz#sha256=49c5838d90e83217909db3789d30a105385b5e696ec5168cda645546c542f35a (from https://pypi.org/simple/psycopg2/) (requires-python:>=2.7,!=3.0.*,!=3.1.*,!=3.2.*,!=3.3.*). Command errored out with exit status 1: python setup.py egg_info Check the logs for full command output.
#   Downloading psycopg2-2.7.7.tar.gz (427 kB)
#      |████████████████████████████████| 427 kB 2.1 MB/s eta 0:00:01
#     ERROR: Command errored out with exit status 1:
#      command: /Users/tarunsingh/opt/anaconda3/bin/python -c 'import io, os, sys, setuptools, tokenize; sys.argv[0] = '"'"'/private/var/folders/9k/dbx4wylx3hz1c7cj8tms5fkc0000gn/T/pip-install-46qc2s_s/psycopg2_288d8a92b7b247cda912f87ccbdccee5/setup.py'"'"'; __file__='"'"'/private/var/folders/9k/dbx4wylx3hz1c7cj8tms5fkc0000gn/T/pip-install-46qc2s_s/psycopg2_288d8a92b7b247cda912f87ccbdccee5/setup.py'"'"';f = getattr(tokenize, '"'"'open'"'"', open)(__file__) if os.path.exists(__file__) else io.StringIO('"'"'from setuptools import setup; setup()'"'"');code = f.read().replace('"'"'\r\n'"'"', '"'"'\n'"'"');f.close();exec(compile(code, __file__, '"'"'exec'"'"'))' egg_info --egg-base /private/var/folders/9k/dbx4wylx3hz1c7cj8tms5fkc0000gn/T/pip-pip-egg-info-ddrmdmzo
#          cwd: /private/var/folders/9k/dbx4wylx3hz1c7cj8tms5fkc0000gn/T/pip-install-46qc2s_s/psycopg2_288d8a92b7b247cda912f87ccbdccee5/
#     Complete output (23 lines):
#     running egg_info
#     creating /private/var/folders/9k/dbx4wylx3hz1c7cj8tms5fkc0000gn/T/pip-pip-egg-info-ddrmdmzo/psycopg2.egg-info
#     writing /private/var/folders/9k/dbx4wylx3hz1c7cj8tms5fkc0000gn/T/pip-pip-egg-info-ddrmdmzo/psycopg2.egg-info/PKG-INFO
#     writing dependency_links to /private/var/folders/9k/dbx4wylx3hz1c7cj8tms5fkc0000gn/T/pip-pip-egg-info-ddrmdmzo/psycopg2.egg-info/dependency_links.txt
#     writing top-level names to /private/var/folders/9k/dbx4wylx3hz1c7cj8tms5fkc0000gn/T/pip-pip-egg-info-ddrmdmzo/psycopg2.egg-info/top_level.txt
#     writing manifest file '/private/var/folders/9k/dbx4wylx3hz1c7cj8tms5fkc0000gn/T/pip-pip-egg-info-ddrmdmzo/psycopg2.egg-info/SOURCES.txt'
#
#     Error: pg_config executable not found.
#
#     pg_config is required to build psycopg2 from source.  Please add the directory
#     containing pg_config to the $PATH or specify the full executable path with the
#     option:
#
#         python setup.py build_ext --pg-config /path/to/pg_config build ...
#
#     or with the pg_config option in 'setup.cfg'.
#
#     If you prefer to avoid building psycopg2 from source, please install the PyPI
#     'psycopg2-binary' package instead.
#
#     For further information please check the 'doc/src/install.rst' file (also at
#     <http://initd.org/psycopg/docs/install.html>).
#
#     ----------------------------------------
# WARNING: Discarding https://files.pythonhosted.org/packages/63/54/c039eb0f46f9a9406b59a638415c2012ad7be9b4b97bfddb1f48c280df3a/psycopg2-2.7.7.tar.gz#sha256=f4526d078aedd5187d0508aa5f9a01eae6a48a470ed678406da94b4cd6524b7e (from https://pypi.org/simple/psycopg2/). Command errored out with exit status 1: python setup.py egg_info Check the logs for full command output.
#   Downloading psycopg2-2.7.6.1.tar.gz (427 kB)
#      |████████████████████████████████| 427 kB 955 kB/s eta 0:00:01
#     ERROR: Command errored out with exit status 1:
#      command: /Users/tarunsingh/opt/anaconda3/bin/python -c 'import io, os, sys, setuptools, tokenize; sys.argv[0] = '"'"'/private/var/folders/9k/dbx4wylx3hz1c7cj8tms5fkc0000gn/T/pip-install-46qc2s_s/psycopg2_5343dc54b99c47a39d9e67849ff56716/setup.py'"'"'; __file__='"'"'/private/var/folders/9k/dbx4wylx3hz1c7cj8tms5fkc0000gn/T/pip-install-46qc2s_s/psycopg2_5343dc54b99c47a39d9e67849ff56716/setup.py'"'"';f = getattr(tokenize, '"'"'open'"'"', open)(__file__) if os.path.exists(__file__) else io.StringIO('"'"'from setuptools import setup; setup()'"'"');code = f.read().replace('"'"'\r\n'"'"', '"'"'\n'"'"');f.close();exec(compile(code, __file__, '"'"'exec'"'"'))' egg_info --egg-base /private/var/folders/9k/dbx4wylx3hz1c7cj8tms5fkc0000gn/T/pip-pip-egg-info-kvzfd4yj
#          cwd: /private/var/folders/9k/dbx4wylx3hz1c7cj8tms5fkc0000gn/T/pip-install-46qc2s_s/psycopg2_5343dc54b99c47a39d9e67849ff56716/
#     Complete output (23 lines):
#     running egg_info
#     creating /private/var/folders/9k/dbx4wylx3hz1c7cj8tms5fkc0000gn/T/pip-pip-egg-info-kvzfd4yj/psycopg2.egg-info
#     writing /private/var/folders/9k/dbx4wylx3hz1c7cj8tms5fkc0000gn/T/pip-pip-egg-info-kvzfd4yj/psycopg2.egg-info/PKG-INFO
#     writing dependency_links to /private/var/folders/9k/dbx4wylx3hz1c7cj8tms5fkc0000gn/T/pip-pip-egg-info-kvzfd4yj/psycopg2.egg-info/dependency_links.txt
#     writing top-level names to /private/var/folders/9k/dbx4wylx3hz1c7cj8tms5fkc0000gn/T/pip-pip-egg-info-kvzfd4yj/psycopg2.egg-info/top_level.txt
#     writing manifest file '/private/var/folders/9k/dbx4wylx3hz1c7cj8tms5fkc0000gn/T/pip-pip-egg-info-kvzfd4yj/psycopg2.egg-info/SOURCES.txt'
#
#     Error: pg_config executable not found.
#
#     pg_config is required to build psycopg2 from source.  Please add the directory
#     containing pg_config to the $PATH or specify the full executable path with the
#     option:
#
#         python setup.py build_ext --pg-config /path/to/pg_config build ...
#
#     or with the pg_config option in 'setup.cfg'.
#
#     If you prefer to avoid building psycopg2 from source, please install the PyPI
#     'psycopg2-binary' package instead.
#
#     For further information please check the 'doc/src/install.rst' file (also at
#     <http://initd.org/psycopg/docs/install.html>).
#
#     ----------------------------------------
# WARNING: Discarding https://files.pythonhosted.org/packages/c0/07/93573b97ed61b6fb907c8439bf58f09957564cf7c39612cef36c547e68c6/psycopg2-2.7.6.1.tar.gz#sha256=27959abe64ca1fc6d8cd11a71a1f421d8287831a3262bd4cacd43bbf43cc3c82 (from https://pypi.org/simple/psycopg2/). Command errored out with exit status 1: python setup.py egg_info Check the logs for full command output.
#   Downloading psycopg2-2.7.6.tar.gz (427 kB)
#      |████████████████████████████████| 427 kB 1.9 MB/s eta 0:00:01
#     ERROR: Command errored out with exit status 1:
#      command: /Users/tarunsingh/opt/anaconda3/bin/python -c 'import io, os, sys, setuptools, tokenize; sys.argv[0] = '"'"'/private/var/folders/9k/dbx4wylx3hz1c7cj8tms5fkc0000gn/T/pip-install-46qc2s_s/psycopg2_e2eaa9eefd9e423d9f3c1807a3d2d181/setup.py'"'"'; __file__='"'"'/private/var/folders/9k/dbx4wylx3hz1c7cj8tms5fkc0000gn/T/pip-install-46qc2s_s/psycopg2_e2eaa9eefd9e423d9f3c1807a3d2d181/setup.py'"'"';f = getattr(tokenize, '"'"'open'"'"', open)(__file__) if os.path.exists(__file__) else io.StringIO('"'"'from setuptools import setup; setup()'"'"');code = f.read().replace('"'"'\r\n'"'"', '"'"'\n'"'"');f.close();exec(compile(code, __file__, '"'"'exec'"'"'))' egg_info --egg-base /private/var/folders/9k/dbx4wylx3hz1c7cj8tms5fkc0000gn/T/pip-pip-egg-info-zcxvqgdl
#          cwd: /private/var/folders/9k/dbx4wylx3hz1c7cj8tms5fkc0000gn/T/pip-install-46qc2s_s/psycopg2_e2eaa9eefd9e423d9f3c1807a3d2d181/
#     Complete output (23 lines):
#     running egg_info
#     creating /private/var/folders/9k/dbx4wylx3hz1c7cj8tms5fkc0000gn/T/pip-pip-egg-info-zcxvqgdl/psycopg2.egg-info
#     writing /private/var/folders/9k/dbx4wylx3hz1c7cj8tms5fkc0000gn/T/pip-pip-egg-info-zcxvqgdl/psycopg2.egg-info/PKG-INFO
#     writing dependency_links to /private/var/folders/9k/dbx4wylx3hz1c7cj8tms5fkc0000gn/T/pip-pip-egg-info-zcxvqgdl/psycopg2.egg-info/dependency_links.txt
#     writing top-level names to /private/var/folders/9k/dbx4wylx3hz1c7cj8tms5fkc0000gn/T/pip-pip-egg-info-zcxvqgdl/psycopg2.egg-info/top_level.txt
#     writing manifest file '/private/var/folders/9k/dbx4wylx3hz1c7cj8tms5fkc0000gn/T/pip-pip-egg-info-zcxvqgdl/psycopg2.egg-info/SOURCES.txt'
#
#     Error: pg_config executable not found.
#
#     pg_config is required to build psycopg2 from source.  Please add the directory
#     containing pg_config to the $PATH or specify the full executable path with the
#     option:
#
#         python setup.py build_ext --pg-config /path/to/pg_config build ...
#
#     or with the pg_config option in 'setup.cfg'.
#
#     If you prefer to avoid building psycopg2 from source, please install the PyPI
#     'psycopg2-binary' package instead.
#
#     For further information please check the 'doc/src/install.rst' file (also at
#     <http://initd.org/psycopg/docs/install.html>).
#
#     ----------------------------------------
# WARNING: Discarding https://files.pythonhosted.org/packages/94/09/2f1fae36d83e2315b90ee91738d01baf8af8c945726bf4b4708fcec3256d/psycopg2-2.7.6.tar.gz#sha256=4a658550b0bcb259e97f77f2dc93ed6b108fe2eda963a9e6fc8b48040d542ec2 (from https://pypi.org/simple/psycopg2/). Command errored out with exit status 1: python setup.py egg_info Check the logs for full command output.
#   Downloading psycopg2-2.7.5.tar.gz (426 kB)
#      |████████████████████████████████| 426 kB 767 kB/s eta 0:00:01
#     ERROR: Command errored out with exit status 1:
#      command: /Users/tarunsingh/opt/anaconda3/bin/python -c 'import io, os, sys, setuptools, tokenize; sys.argv[0] = '"'"'/private/var/folders/9k/dbx4wylx3hz1c7cj8tms5fkc0000gn/T/pip-install-46qc2s_s/psycopg2_05a96309537541a0bee4fbc312363417/setup.py'"'"'; __file__='"'"'/private/var/folders/9k/dbx4wylx3hz1c7cj8tms5fkc0000gn/T/pip-install-46qc2s_s/psycopg2_05a96309537541a0bee4fbc312363417/setup.py'"'"';f = getattr(tokenize, '"'"'open'"'"', open)(__file__) if os.path.exists(__file__) else io.StringIO('"'"'from setuptools import setup; setup()'"'"');code = f.read().replace('"'"'\r\n'"'"', '"'"'\n'"'"');f.close();exec(compile(code, __file__, '"'"'exec'"'"'))' egg_info --egg-base /private/var/folders/9k/dbx4wylx3hz1c7cj8tms5fkc0000gn/T/pip-pip-egg-info-sa5rgjpj
#          cwd: /private/var/folders/9k/dbx4wylx3hz1c7cj8tms5fkc0000gn/T/pip-install-46qc2s_s/psycopg2_05a96309537541a0bee4fbc312363417/
#     Complete output (23 lines):
#     running egg_info
#     creating /private/var/folders/9k/dbx4wylx3hz1c7cj8tms5fkc0000gn/T/pip-pip-egg-info-sa5rgjpj/psycopg2.egg-info
#     writing /private/var/folders/9k/dbx4wylx3hz1c7cj8tms5fkc0000gn/T/pip-pip-egg-info-sa5rgjpj/psycopg2.egg-info/PKG-INFO
#     writing dependency_links to /private/var/folders/9k/dbx4wylx3hz1c7cj8tms5fkc0000gn/T/pip-pip-egg-info-sa5rgjpj/psycopg2.egg-info/dependency_links.txt
#     writing top-level names to /private/var/folders/9k/dbx4wylx3hz1c7cj8tms5fkc0000gn/T/pip-pip-egg-info-sa5rgjpj/psycopg2.egg-info/top_level.txt
#     writing manifest file '/private/var/folders/9k/dbx4wylx3hz1c7cj8tms5fkc0000gn/T/pip-pip-egg-info-sa5rgjpj/psycopg2.egg-info/SOURCES.txt'
#
#     Error: pg_config executable not found.
#
#     pg_config is required to build psycopg2 from source.  Please add the directory
#     containing pg_config to the $PATH or specify the full executable path with the
#     option:
#
#         python setup.py build_ext --pg-config /path/to/pg_config build ...
#
#     or with the pg_config option in 'setup.cfg'.
#
#     If you prefer to avoid building psycopg2 from source, please install the PyPI
#     'psycopg2-binary' package instead.
#
#     For further information please check the 'doc/src/install.rst' file (also at
#     <http://initd.org/psycopg/docs/install.html>).
#
#     ----------------------------------------
# WARNING: Discarding https://files.pythonhosted.org/packages/b2/c1/7bf6c464e903ffc4f3f5907c389e5a4199666bf57f6cd6bf46c17912a1f9/psycopg2-2.7.5.tar.gz#sha256=eccf962d41ca46e6326b97c8fe0a6687b58dfc1a5f6540ed071ff1474cea749e (from https://pypi.org/simple/psycopg2/). Command errored out with exit status 1: python setup.py egg_info Check the logs for full command output.
#   Downloading psycopg2-2.7.4.tar.gz (425 kB)
#      |████████████████████████████████| 425 kB 1.2 MB/s eta 0:00:01
#     ERROR: Command errored out with exit status 1:
#      command: /Users/tarunsingh/opt/anaconda3/bin/python -c 'import io, os, sys, setuptools, tokenize; sys.argv[0] = '"'"'/private/var/folders/9k/dbx4wylx3hz1c7cj8tms5fkc0000gn/T/pip-install-46qc2s_s/psycopg2_a0792f2e1c1148f98111cf1fa4034e5c/setup.py'"'"'; __file__='"'"'/private/var/folders/9k/dbx4wylx3hz1c7cj8tms5fkc0000gn/T/pip-install-46qc2s_s/psycopg2_a0792f2e1c1148f98111cf1fa4034e5c/setup.py'"'"';f = getattr(tokenize, '"'"'open'"'"', open)(__file__) if os.path.exists(__file__) else io.StringIO('"'"'from setuptools import setup; setup()'"'"');code = f.read().replace('"'"'\r\n'"'"', '"'"'\n'"'"');f.close();exec(compile(code, __file__, '"'"'exec'"'"'))' egg_info --egg-base /private/var/folders/9k/dbx4wylx3hz1c7cj8tms5fkc0000gn/T/pip-pip-egg-info-hxqvnjsu
#          cwd: /private/var/folders/9k/dbx4wylx3hz1c7cj8tms5fkc0000gn/T/pip-install-46qc2s_s/psycopg2_a0792f2e1c1148f98111cf1fa4034e5c/
#     Complete output (23 lines):
#     running egg_info
#     creating /private/var/folders/9k/dbx4wylx3hz1c7cj8tms5fkc0000gn/T/pip-pip-egg-info-hxqvnjsu/psycopg2.egg-info
#     writing /private/var/folders/9k/dbx4wylx3hz1c7cj8tms5fkc0000gn/T/pip-pip-egg-info-hxqvnjsu/psycopg2.egg-info/PKG-INFO
#     writing dependency_links to /private/var/folders/9k/dbx4wylx3hz1c7cj8tms5fkc0000gn/T/pip-pip-egg-info-hxqvnjsu/psycopg2.egg-info/dependency_links.txt
#     writing top-level names to /private/var/folders/9k/dbx4wylx3hz1c7cj8tms5fkc0000gn/T/pip-pip-egg-info-hxqvnjsu/psycopg2.egg-info/top_level.txt
#     writing manifest file '/private/var/folders/9k/dbx4wylx3hz1c7cj8tms5fkc0000gn/T/pip-pip-egg-info-hxqvnjsu/psycopg2.egg-info/SOURCES.txt'
#
#     Error: pg_config executable not found.
#
#     pg_config is required to build psycopg2 from source.  Please add the directory
#     containing pg_config to the $PATH or specify the full executable path with the
#     option:
#
#         python setup.py build_ext --pg-config /path/to/pg_config build ...
#
#     or with the pg_config option in 'setup.cfg'.
#
#     If you prefer to avoid building psycopg2 from source, please install the PyPI
#     'psycopg2-binary' package instead.
#
#     For further information please check the 'doc/src/install.rst' file (also at
#     <http://initd.org/psycopg/docs/install.html>).
#
#     ----------------------------------------
# WARNING: Discarding https://files.pythonhosted.org/packages/74/83/51580322ed0e82cba7ad8e0af590b8fb2cf11bd5aaa1ed872661bd36f462/psycopg2-2.7.4.tar.gz#sha256=8bf51191d60f6987482ef0cfe8511bbf4877a5aa7f313d7b488b53189cf26209 (from https://pypi.org/simple/psycopg2/). Command errored out with exit status 1: python setup.py egg_info Check the logs for full command output.
#   Downloading psycopg2-2.7.3.2.tar.gz (425 kB)
#      |████████████████████████████████| 425 kB 2.1 MB/s eta 0:00:01
#     ERROR: Command errored out with exit status 1:
# ...
#   Downloading psycopg2-2.2.2.tar.gz (530 kB)
#      |████████████████████████████████| 530 kB 499 kB/s eta 0:00:01
#     ERROR: Command errored out with exit status 1:
#      command: /Users/tarunsingh/opt/anaconda3/bin/python -c 'import io, os, sys, setuptools, tokenize; sys.argv[0] = '"'"'/private/var/folders/9k/dbx4wylx3hz1c7cj8tms5fkc0000gn/T/pip-install-46qc2s_s/psycopg2_b924f86ba81e488e9748d14379231c5d/setup.py'"'"'; __file__='"'"'/private/var/folders/9k/dbx4wylx3hz1c7cj8tms5fkc0000gn/T/pip-install-46qc2s_s/psycopg2_b924f86ba81e488e9748d14379231c5d/setup.py'"'"';f = getattr(tokenize, '"'"'open'"'"', open)(__file__) if os.path.exists(__file__) else io.StringIO('"'"'from setuptools import setup; setup()'"'"');code = f.read().replace('"'"'\r\n'"'"', '"'"'\n'"'"');f.close();exec(compile(code, __file__, '"'"'exec'"'"'))' egg_info --egg-base /private/var/folders/9k/dbx4wylx3hz1c7cj8tms5fkc0000gn/T/pip-pip-egg-info-8vclfpc3
#          cwd: /private/var/folders/9k/dbx4wylx3hz1c7cj8tms5fkc0000gn/T/pip-install-46qc2s_s/psycopg2_b924f86ba81e488e9748d14379231c5d/
#     Complete output (6 lines):
#     Traceback (most recent call last):
#       File "<string>", line 1, in <module>
#       File "/private/var/folders/9k/dbx4wylx3hz1c7cj8tms5fkc0000gn/T/pip-install-46qc2s_s/psycopg2_b924f86ba81e488e9748d14379231c5d/setup.py", line 245
#         except Warning, w:
#                       ^
#     SyntaxError: invalid syntax
#     ----------------------------------------
# WARNING: Discarding https://files.pythonhosted.org/packages/63/3e/a4a35761eb4595fff89e63347b4f8e79c2095782fa5bc016a6dfb18b21ac/psycopg2-2.2.2.tar.gz#sha256=21a33d5b2609103512748098a06249492cc294790e07638fadc68cf06eeac39d (from https://pypi.org/simple/psycopg2/). Command errored out with exit status 1: python setup.py egg_info Check the logs for full command output.
#   Downloading psycopg2-2.2.1.tar.gz (529 kB)
#      |████████████████████████████████| 529 kB 399 kB/s eta 0:00:01
#     ERROR: Command errored out with exit status 1:
#      command: /Users/tarunsingh/opt/anaconda3/bin/python -c 'import io, os, sys, setuptools, tokenize; sys.argv[0] = '"'"'/private/var/folders/9k/dbx4wylx3hz1c7cj8tms5fkc0000gn/T/pip-install-46qc2s_s/psycopg2_17a939ce6c6148e8b80b848b44a5ce09/setup.py'"'"'; __file__='"'"'/private/var/folders/9k/dbx4wylx3hz1c7cj8tms5fkc0000gn/T/pip-install-46qc2s_s/psycopg2_17a939ce6c6148e8b80b848b44a5ce09/setup.py'"'"';f = getattr(tokenize, '"'"'open'"'"', open)(__file__) if os.path.exists(__file__) else io.StringIO('"'"'from setuptools import setup; setup()'"'"');code = f.read().replace('"'"'\r\n'"'"', '"'"'\n'"'"');f.close();exec(compile(code, __file__, '"'"'exec'"'"'))' egg_info --egg-base /private/var/folders/9k/dbx4wylx3hz1c7cj8tms5fkc0000gn/T/pip-pip-egg-info-oawjoq6w
#          cwd: /private/var/folders/9k/dbx4wylx3hz1c7cj8tms5fkc0000gn/T/pip-install-46qc2s_s/psycopg2_17a939ce6c6148e8b80b848b44a5ce09/
#     Complete output (6 lines):
#     Traceback (most recent call last):
#       File "<string>", line 1, in <module>
#       File "/private/var/folders/9k/dbx4wylx3hz1c7cj8tms5fkc0000gn/T/pip-install-46qc2s_s/psycopg2_17a939ce6c6148e8b80b848b44a5ce09/setup.py", line 239
#         except Warning, w:
#                       ^
#     SyntaxError: invalid syntax
#     ----------------------------------------
# WARNING: Discarding https://files.pythonhosted.org/packages/de/c4/fdfb801035bd7da9e1ce98169d48ca2d6dee5b4361e349afbba40b3d7a5d/psycopg2-2.2.1.tar.gz#sha256=b0eca4e8438025dc57cacbea4e8ca2f5dc0554d41b1cdcc177757a5fc413f3d1 (from https://pypi.org/simple/psycopg2/). Command errored out with exit status 1: python setup.py egg_info Check the logs for full command output.
#   Downloading psycopg2-2.2.0.tar.gz (528 kB)
#      |████████████████████████████████| 528 kB 269 kB/s eta 0:00:01
#     ERROR: Command errored out with exit status 1:
#      command: /Users/tarunsingh/opt/anaconda3/bin/python -c 'import io, os, sys, setuptools, tokenize; sys.argv[0] = '"'"'/private/var/folders/9k/dbx4wylx3hz1c7cj8tms5fkc0000gn/T/pip-install-46qc2s_s/psycopg2_a6aa05756f654a1091491dcb2d6508e0/setup.py'"'"'; __file__='"'"'/private/var/folders/9k/dbx4wylx3hz1c7cj8tms5fkc0000gn/T/pip-install-46qc2s_s/psycopg2_a6aa05756f654a1091491dcb2d6508e0/setup.py'"'"';f = getattr(tokenize, '"'"'open'"'"', open)(__file__) if os.path.exists(__file__) else io.StringIO('"'"'from setuptools import setup; setup()'"'"');code = f.read().replace('"'"'\r\n'"'"', '"'"'\n'"'"');f.close();exec(compile(code, __file__, '"'"'exec'"'"'))' egg_info --egg-base /private/var/folders/9k/dbx4wylx3hz1c7cj8tms5fkc0000gn/T/pip-pip-egg-info-t6_gnzp0
#          cwd: /private/var/folders/9k/dbx4wylx3hz1c7cj8tms5fkc0000gn/T/pip-install-46qc2s_s/psycopg2_a6aa05756f654a1091491dcb2d6508e0/
#     Complete output (6 lines):
#     Traceback (most recent call last):
#       File "<string>", line 1, in <module>
#       File "/private/var/folders/9k/dbx4wylx3hz1c7cj8tms5fkc0000gn/T/pip-install-46qc2s_s/psycopg2_a6aa05756f654a1091491dcb2d6508e0/setup.py", line 238
#         except Warning, w:
#                       ^
#     SyntaxError: invalid syntax
#     ----------------------------------------
# WARNING: Discarding https://files.pythonhosted.org/packages/32/0c/2f4da04ae2a66d71eff37f19fce67506ad28f887851cd1c1cca35ba08b36/psycopg2-2.2.0.tar.gz#sha256=e70a8eabc491318beef4cd9cd9245a4d8dc62ee31cb74e7988913a66bb33f858 (from https://pypi.org/simple/psycopg2/). Command errored out with exit status 1: python setup.py egg_info Check the logs for full command output.
#   Downloading psycopg2-2.0.14.tar.gz (491 kB)
#      |████████████████████████████████| 491 kB 461 kB/s eta 0:00:01
#     ERROR: Command errored out with exit status 1:
#      command: /Users/tarunsingh/opt/anaconda3/bin/python -c 'import io, os, sys, setuptools, tokenize; sys.argv[0] = '"'"'/private/var/folders/9k/dbx4wylx3hz1c7cj8tms5fkc0000gn/T/pip-install-46qc2s_s/psycopg2_b188596cd094440382ea059af5b6a79a/setup.py'"'"'; __file__='"'"'/private/var/folders/9k/dbx4wylx3hz1c7cj8tms5fkc0000gn/T/pip-install-46qc2s_s/psycopg2_b188596cd094440382ea059af5b6a79a/setup.py'"'"';f = getattr(tokenize, '"'"'open'"'"', open)(__file__) if os.path.exists(__file__) else io.StringIO('"'"'from setuptools import setup; setup()'"'"');code = f.read().replace('"'"'\r\n'"'"', '"'"'\n'"'"');f.close();exec(compile(code, __file__, '"'"'exec'"'"'))' egg_info --egg-base /private/var/folders/9k/dbx4wylx3hz1c7cj8tms5fkc0000gn/T/pip-pip-egg-info-kwzobvwa
#          cwd: /private/var/folders/9k/dbx4wylx3hz1c7cj8tms5fkc0000gn/T/pip-install-46qc2s_s/psycopg2_b188596cd094440382ea059af5b6a79a/
#     Complete output (6 lines):
#     Traceback (most recent call last):
#       File "<string>", line 1, in <module>
#       File "/private/var/folders/9k/dbx4wylx3hz1c7cj8tms5fkc0000gn/T/pip-install-46qc2s_s/psycopg2_b188596cd094440382ea059af5b6a79a/setup.py", line 238
#         except Warning, w:
#                       ^
#     SyntaxError: invalid syntax
#     ----------------------------------------
# WARNING: Discarding https://files.pythonhosted.org/packages/e0/1c/f0843f50a69fba3db880e9b267d36f6709bbf31a36fc46b82f75e8975ede/psycopg2-2.0.14.tar.gz#sha256=902607cdbe1195a00694d2b477eed8429eda433caaa0eb6ff7f80883e1c17ac7 (from https://pypi.org/simple/psycopg2/). Command errored out with exit status 1: python setup.py egg_info Check the logs for full command output.
#   Downloading psycopg2-2.0.13.tar.gz (258 kB)
#      |████████████████████████████████| 258 kB 643 kB/s eta 0:00:01
#     ERROR: Command errored out with exit status 1:
#      command: /Users/tarunsingh/opt/anaconda3/bin/python -c 'import io, os, sys, setuptools, tokenize; sys.argv[0] = '"'"'/private/var/folders/9k/dbx4wylx3hz1c7cj8tms5fkc0000gn/T/pip-install-46qc2s_s/psycopg2_cbbf670b126d43ce8b6099ff9cb77b19/setup.py'"'"'; __file__='"'"'/private/var/folders/9k/dbx4wylx3hz1c7cj8tms5fkc0000gn/T/pip-install-46qc2s_s/psycopg2_cbbf670b126d43ce8b6099ff9cb77b19/setup.py'"'"';f = getattr(tokenize, '"'"'open'"'"', open)(__file__) if os.path.exists(__file__) else io.StringIO('"'"'from setuptools import setup; setup()'"'"');code = f.read().replace('"'"'\r\n'"'"', '"'"'\n'"'"');f.close();exec(compile(code, __file__, '"'"'exec'"'"'))' egg_info --egg-base /private/var/folders/9k/dbx4wylx3hz1c7cj8tms5fkc0000gn/T/pip-pip-egg-info-x308su0i
#          cwd: /private/var/folders/9k/dbx4wylx3hz1c7cj8tms5fkc0000gn/T/pip-install-46qc2s_s/psycopg2_cbbf670b126d43ce8b6099ff9cb77b19/
#     Complete output (6 lines):
#     Traceback (most recent call last):
#       File "<string>", line 1, in <module>
#       File "/private/var/folders/9k/dbx4wylx3hz1c7cj8tms5fkc0000gn/T/pip-install-46qc2s_s/psycopg2_cbbf670b126d43ce8b6099ff9cb77b19/setup.py", line 233
#         except Warning, w:
#                       ^
#     SyntaxError: invalid syntax
#     ----------------------------------------
# WARNING: Discarding https://files.pythonhosted.org/packages/3a/7a/968afcb86b1958ae963a3aaa42c561e3ed2c2d4a8b773622b03856a16248/psycopg2-2.0.13.tar.gz#sha256=a15e622e101b16aa8ad44813d8fb1eced91379396c054aacbfa3ad658352332b (from https://pypi.org/simple/psycopg2/). Command errored out with exit status 1: python setup.py egg_info Check the logs for full command output.
#   Downloading psycopg2-2.0.12.tar.gz (256 kB)
#      |████████████████████████████████| 256 kB 338 kB/s eta 0:00:01
#     ERROR: Command errored out with exit status 1:
#      command: /Users/tarunsingh/opt/anaconda3/bin/python -c 'import io, os, sys, setuptools, tokenize; sys.argv[0] = '"'"'/private/var/folders/9k/dbx4wylx3hz1c7cj8tms5fkc0000gn/T/pip-install-46qc2s_s/psycopg2_5d6cdc09cff044afa08078cfc6a9053d/setup.py'"'"'; __file__='"'"'/private/var/folders/9k/dbx4wylx3hz1c7cj8tms5fkc0000gn/T/pip-install-46qc2s_s/psycopg2_5d6cdc09cff044afa08078cfc6a9053d/setup.py'"'"';f = getattr(tokenize, '"'"'open'"'"', open)(__file__) if os.path.exists(__file__) else io.StringIO('"'"'from setuptools import setup; setup()'"'"');code = f.read().replace('"'"'\r\n'"'"', '"'"'\n'"'"');f.close();exec(compile(code, __file__, '"'"'exec'"'"'))' egg_info --egg-base /private/var/folders/9k/dbx4wylx3hz1c7cj8tms5fkc0000gn/T/pip-pip-egg-info-jd01oyoe
#          cwd: /private/var/folders/9k/dbx4wylx3hz1c7cj8tms5fkc0000gn/T/pip-install-46qc2s_s/psycopg2_5d6cdc09cff044afa08078cfc6a9053d/
#     Complete output (6 lines):
#     Traceback (most recent call last):
#       File "<string>", line 1, in <module>
#       File "/private/var/folders/9k/dbx4wylx3hz1c7cj8tms5fkc0000gn/T/pip-install-46qc2s_s/psycopg2_5d6cdc09cff044afa08078cfc6a9053d/setup.py", line 225
#         except Warning, w:
#                       ^
#     SyntaxError: invalid syntax
#     ----------------------------------------
# WARNING: Discarding https://files.pythonhosted.org/packages/6a/8d/ee5c330823d527a5cd14c833063f825211d7b5de6e4897f72e250c107d85/psycopg2-2.0.12.tar.gz#sha256=542c187531e756867fb60034c393b6f2beca34eeeb3ce2e0089a2b6fb8be1292 (from https://pypi.org/simple/psycopg2/). Command errored out with exit status 1: python setup.py egg_info Check the logs for full command output.
#   Downloading psycopg2-2.0.11.tar.gz (255 kB)
#      |████████████████████████████████| 255 kB 228 kB/s eta 0:00:01
#     ERROR: Command errored out with exit status 1:
#      command: /Users/tarunsingh/opt/anaconda3/bin/python -c 'import io, os, sys, setuptools, tokenize; sys.argv[0] = '"'"'/private/var/folders/9k/dbx4wylx3hz1c7cj8tms5fkc0000gn/T/pip-install-46qc2s_s/psycopg2_f77e90c5d6574750a53a7fbeeed65cac/setup.py'"'"'; __file__='"'"'/private/var/folders/9k/dbx4wylx3hz1c7cj8tms5fkc0000gn/T/pip-install-46qc2s_s/psycopg2_f77e90c5d6574750a53a7fbeeed65cac/setup.py'"'"';f = getattr(tokenize, '"'"'open'"'"', open)(__file__) if os.path.exists(__file__) else io.StringIO('"'"'from setuptools import setup; setup()'"'"');code = f.read().replace('"'"'\r\n'"'"', '"'"'\n'"'"');f.close();exec(compile(code, __file__, '"'"'exec'"'"'))' egg_info --egg-base /private/var/folders/9k/dbx4wylx3hz1c7cj8tms5fkc0000gn/T/pip-pip-egg-info-bwey0my_
#          cwd: /private/var/folders/9k/dbx4wylx3hz1c7cj8tms5fkc0000gn/T/pip-install-46qc2s_s/psycopg2_f77e90c5d6574750a53a7fbeeed65cac/
#     Complete output (6 lines):
#     Traceback (most recent call last):
#       File "<string>", line 1, in <module>
#       File "/private/var/folders/9k/dbx4wylx3hz1c7cj8tms5fkc0000gn/T/pip-install-46qc2s_s/psycopg2_f77e90c5d6574750a53a7fbeeed65cac/setup.py", line 225
#         except Warning, w:
#                       ^
#     SyntaxError: invalid syntax
#     ----------------------------------------
# WARNING: Discarding https://files.pythonhosted.org/packages/2d/d7/496da11d7c81971870ddd36800419c4f84e8f6208aac5eabedf9f7748729/psycopg2-2.0.11.tar.gz#sha256=e6b4e0e41df97441eff34e00065376414da6488e0d55848a45cd77551dbae434 (from https://pypi.org/simple/psycopg2/). Command errored out with exit status 1: python setup.py egg_info Check the logs for full command output.
#   Downloading psycopg2-2.0.10.tar.gz (255 kB)
#      |████████████████████████████████| 255 kB 989 kB/s eta 0:00:01
#     ERROR: Command errored out with exit status 1:
#      command: /Users/tarunsingh/opt/anaconda3/bin/python -c 'import io, os, sys, setuptools, tokenize; sys.argv[0] = '"'"'/private/var/folders/9k/dbx4wylx3hz1c7cj8tms5fkc0000gn/T/pip-install-46qc2s_s/psycopg2_f2555c7e4507405d93e386fd35e42e29/setup.py'"'"'; __file__='"'"'/private/var/folders/9k/dbx4wylx3hz1c7cj8tms5fkc0000gn/T/pip-install-46qc2s_s/psycopg2_f2555c7e4507405d93e386fd35e42e29/setup.py'"'"';f = getattr(tokenize, '"'"'open'"'"', open)(__file__) if os.path.exists(__file__) else io.StringIO('"'"'from setuptools import setup; setup()'"'"');code = f.read().replace('"'"'\r\n'"'"', '"'"'\n'"'"');f.close();exec(compile(code, __file__, '"'"'exec'"'"'))' egg_info --egg-base /private/var/folders/9k/dbx4wylx3hz1c7cj8tms5fkc0000gn/T/pip-pip-egg-info-k1dcphzn
#          cwd: /private/var/folders/9k/dbx4wylx3hz1c7cj8tms5fkc0000gn/T/pip-install-46qc2s_s/psycopg2_f2555c7e4507405d93e386fd35e42e29/
#     Complete output (5 lines):
#     Traceback (most recent call last):
#       File "<string>", line 1, in <module>
#       File "/private/var/folders/9k/dbx4wylx3hz1c7cj8tms5fkc0000gn/T/pip-install-46qc2s_s/psycopg2_f2555c7e4507405d93e386fd35e42e29/setup.py", line 50, in <module>
#         import ConfigParser
#     ModuleNotFoundError: No module named 'ConfigParser'
#     ----------------------------------------
# WARNING: Discarding https://files.pythonhosted.org/packages/19/79/35c7596bab4456f3610c12ec542a94d51c6781ced587d1d85127210b879b/psycopg2-2.0.10.tar.gz#sha256=e40cc04b43849085725076ae134bfef9e3b087f6dd7c964aeeb930e2f0bc14ab (from https://pypi.org/simple/psycopg2/). Command errored out with exit status 1: python setup.py egg_info Check the logs for full command output.
# Collecting pulsar-odm
#   Downloading pulsar_odm-0.6.2-py3-none-any.whl (20 kB)
# Collecting pulsar
#   Using cached pulsar-2.0.2-py3-none-any.whl (280 kB)
# Collecting pulsar-odm
#   Downloading pulsar_odm-0.6.1-py3-none-any.whl (20 kB)
#   Downloading pulsar_odm-0.6.0-py3-none-any.whl (20 kB)
#   Downloading pulsar_odm-0.5.0-py3-none-any.whl (20 kB)
#   Downloading pulsar-odm-0.4.0.tar.gz (14 kB)
# Collecting multidict
#   Using cached multidict-6.0.2-cp39-cp39-macosx_10_9_x86_64.whl (28 kB)
# Requirement already satisfied: six>=1.5 in /Users/tarunsingh/opt/anaconda3/lib/python3.9/site-packages (from python-dateutil->lux) (1.16.0)
# Building wheels for collected packages: pulsar-odm
#   Building wheel for pulsar-odm (setup.py) ... done
#   Created wheel for pulsar-odm: filename=pulsar_odm-0.4.0-py2.py3-none-any.whl size=16531 sha256=ddf693277e4249d88063dc25e1d34c704cb7d3d3f0fcddd2484da01549a3ce86
#   Stored in directory: /Users/tarunsingh/Library/Caches/pip/wheels/f4/22/b8/6ae740c273bed0145d9fb594903cc80111b4901e3b610350f5
# Successfully built pulsar-odm
# Installing collected packages: multidict, pulsar, pulsar-odm, lux
# Successfully installed lux-0.8.2 multidict-6.0.2 pulsar-2.0.2 pulsar-odm-0.4.0

# %%
import lux
df3
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# 0      man        True  NaN  Southampton    no  False
# 1    woman       False    C    Cherbourg   yes  False
# 2    woman       False  NaN  Southampton   yes   True
# 3    woman       False    C  Southampton   yes  False
# 4      man        True  NaN  Southampton    no   True
# ..     ...         ...  ...          ...   ...    ...
# 886    man        True  NaN  Southampton    no   True
# 887  woman       False    B  Southampton   yes   True
# 888  woman       False  NaN  Southampton    no  False
# 889    man        True    C    Cherbourg   yes   True
# 890    man        True  NaN   Queenstown    no   True
#
# [891 rows x 15 columns]
# Executing shutdown due to inactivity...
# 2022-02-23 19:23:14,132 - INFO     - Executing shutdown due to inactivity...
# Executing shutdown...
# 2022-02-23 19:23:14,427 - INFO     - Executing shutdown...
